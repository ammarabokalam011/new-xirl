# %%
import os
import glob
import numpy as np
import torch
from torch_geometric.data import Data
from torchvision import models, transforms
from PIL import Image
from sklearn.neighbors import NearestNeighbors

# %%
def get_edge_info(num_frame):
    skip = skip_factor
    node_source = []
    node_target = []
    edge_attr = []
    for i in range(num_frame):
        for j in range(num_frame):
            frame_diff = i - j
            if abs(frame_diff) <= tauf:
                node_source.append(i)
                node_target.append(j)
                edge_attr.append(np.sign(frame_diff))
            elif skip:
                if (frame_diff % skip == 0) and (abs(frame_diff) <= skip * tauf):
                    node_source.append(i)
                    node_target.append(j)
                    edge_attr.append(np.sign(frame_diff))
    return node_source, node_target, edge_attr

# %%
def extract_features(image_path):
    resnet = models.resnet50(pretrained=True)
    modules = list(resnet.children())[:-1]
    resnet = torch.nn.Sequential(*modules)
    resnet.eval()

    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    img = Image.open(image_path).convert('RGB')
    img_tensor = preprocess(img).unsqueeze(0)

    with torch.no_grad():
        features = resnet(img_tensor)

    return features.view(features.size(0), -1).numpy()

# %%
def generate_temporal_graph(image_folder):
    image_files = sorted(glob.glob(os.path.join(image_folder, '*.png')))
    num_frame = len(image_files)

    features = []
    
    print(f"Extracting features from {num_frame} images in {image_folder}...")
    
    # Extract features for each image file
    for img_file in image_files:
        feature_vector = extract_features(img_file)
        features.append(feature_vector)

    features = np.array(features).squeeze()

    # Get edge information within the same video
    node_source, node_target, edge_attr = get_edge_info(num_frame)

    return features, node_source, node_target, edge_attr

# %%
embodiment = 'mediumstick'
root_data = f'./data/{embodiment}'
tauf = 5
skip_factor = 10

dataset_folder = f'/tmp/xirl/datasets/xmagical/train/{embodiment}'
output_graphs_path = os.path.join(root_data, 'graphs')
os.makedirs(output_graphs_path, exist_ok=True)

all_graphs = []

# %%
def connect_videos_with_knn(all_graphs):
    all_features = []
    
    # Collect all features from all videos
    for features, _, _, _ in all_graphs:
        all_features.append(features)
    
    all_features = np.vstack(all_features)  # Combine features from all videos
    
    # Create a k-NN model to find nearest neighbors across videos
    knn_model = NearestNeighbors(n_neighbors=5)  # You can adjust n_neighbors as needed
    knn_model.fit(all_features)

    edges_from_other_videos = []

    # Create edges based on nearest neighbors
    start_index = 0  # To keep track of where each video's features start in the combined array

    print("Connecting images between videos using k-NN...")
    
    for video_index, (video_features, _, _, _) in enumerate(all_graphs):
        num_video_frames = video_features.shape[0]
        
        # Find nearest neighbors for each feature vector in the current video across all videos
        distances, indices = knn_model.kneighbors(video_features)

        for i in range(num_video_frames):
            for neighbor_index in indices[i]:
                # Ensure that we do not connect nodes within the same video
                if neighbor_index // num_video_frames != video_index:
                    edges_from_other_videos.append((start_index + i, neighbor_index))

        start_index += num_video_frames

        print(f"Processed video {video_index + 1}/{len(all_graphs)}: {num_video_frames} frames")

    return edges_from_other_videos

# %%
# Iterate through each video folder (0/, 1/, etc.)
video_folders = os.listdir(dataset_folder)
total_videos = len(video_folders)

for video_index, video_folder in enumerate(video_folders):
    full_video_path = os.path.join(dataset_folder, video_folder)
    
    if os.path.isdir(full_video_path):
        features, node_source, node_target, edge_attr = generate_temporal_graph(full_video_path)
        
        # Store graph data as a tuple (features, source nodes, target nodes, edge attributes)
        all_graphs.append((features, node_source, node_target, edge_attr))
        
        print(f"Finished processing video {video_index + 1}/{total_videos}: {video_folder}")
# Out:
# Extracting features from 62 images in /tmp/xirl/datasets/xmagical/train/mediumstick/99...
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Finished processing video 1/877: 99
# Extracting features from 43 images in /tmp/xirl/datasets/xmagical/train/mediumstick/420...
# Finished processing video 2/877: 420
# Extracting features from 52 images in /tmp/xirl/datasets/xmagical/train/mediumstick/868...
# Finished processing video 3/877: 868
# Extracting features from 54 images in /tmp/xirl/datasets/xmagical/train/mediumstick/465...
# Finished processing video 4/877: 465
# Extracting features from 103 images in /tmp/xirl/datasets/xmagical/train/mediumstick/136...
# Finished processing video 5/877: 136
# Extracting features from 58 images in /tmp/xirl/datasets/xmagical/train/mediumstick/323...
# Finished processing video 6/877: 323
# Extracting features from 33 images in /tmp/xirl/datasets/xmagical/train/mediumstick/683...
# Finished processing video 7/877: 683
# Extracting features from 38 images in /tmp/xirl/datasets/xmagical/train/mediumstick/416...
# Finished processing video 8/877: 416
# Extracting features from 39 images in /tmp/xirl/datasets/xmagical/train/mediumstick/421...
# Finished processing video 9/877: 421
# Extracting features from 112 images in /tmp/xirl/datasets/xmagical/train/mediumstick/127...
# Finished processing video 10/877: 127
# Extracting features from 38 images in /tmp/xirl/datasets/xmagical/train/mediumstick/216...
# Finished processing video 11/877: 216
# Extracting features from 62 images in /tmp/xirl/datasets/xmagical/train/mediumstick/808...
# Finished processing video 12/877: 808
# Extracting features from 96 images in /tmp/xirl/datasets/xmagical/train/mediumstick/991...
# Finished processing video 13/877: 991
# Extracting features from 70 images in /tmp/xirl/datasets/xmagical/train/mediumstick/243...
# Finished processing video 14/877: 243
# Extracting features from 53 images in /tmp/xirl/datasets/xmagical/train/mediumstick/75...
# Finished processing video 15/877: 75
# Extracting features from 42 images in /tmp/xirl/datasets/xmagical/train/mediumstick/930...
# Finished processing video 16/877: 930
# Extracting features from 40 images in /tmp/xirl/datasets/xmagical/train/mediumstick/525...
# Finished processing video 17/877: 525
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/mediumstick/654...
# Finished processing video 18/877: 654
# Extracting features from 69 images in /tmp/xirl/datasets/xmagical/train/mediumstick/157...
# Finished processing video 19/877: 157
# Extracting features from 124 images in /tmp/xirl/datasets/xmagical/train/mediumstick/83...
# Finished processing video 20/877: 83
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/mediumstick/867...
# Finished processing video 21/877: 867
# Extracting features from 66 images in /tmp/xirl/datasets/xmagical/train/mediumstick/544...
# Finished processing video 22/877: 544
# Extracting features from 55 images in /tmp/xirl/datasets/xmagical/train/mediumstick/474...
# Finished processing video 23/877: 474
# Extracting features from 24 images in /tmp/xirl/datasets/xmagical/train/mediumstick/70...
# Finished processing video 24/877: 70
# Extracting features from 80 images in /tmp/xirl/datasets/xmagical/train/mediumstick/866...
# Finished processing video 25/877: 866
# Extracting features from 56 images in /tmp/xirl/datasets/xmagical/train/mediumstick/734...
# Finished processing video 26/877: 734
# Extracting features from 59 images in /tmp/xirl/datasets/xmagical/train/mediumstick/374...
# Finished processing video 27/877: 374
# Extracting features from 64 images in /tmp/xirl/datasets/xmagical/train/mediumstick/887...
# Finished processing video 28/877: 887
# Extracting features from 83 images in /tmp/xirl/datasets/xmagical/train/mediumstick/410...
# Finished processing video 29/877: 410
# Extracting features from 48 images in /tmp/xirl/datasets/xmagical/train/mediumstick/546...
# Finished processing video 30/877: 546
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/mediumstick
# Extracting features from 50 images in /tmp/xirl/datasets/xmagical/train/mediumstick/434...
# Finished processing video 843/877: 434
# Extracting features from 96 images in /tmp/xirl/datasets/xmagical/train/mediumstick/40...
# Finished processing video 844/877: 40
# Extracting features from 70 images in /tmp/xirl/datasets/xmagical/train/mediumstick/798...
# Finished processing video 845/877: 798
# Extracting features from 53 images in /tmp/xirl/datasets/xmagical/train/mediumstick/609...
# Finished processing video 846/877: 609
# Extracting features from 41 images in /tmp/xirl/datasets/xmagical/train/mediumstick/146...
# Finished processing video 847/877: 146
# Extracting features from 53 images in /tmp/xirl/datasets/xmagical/train/mediumstick/863...
# Finished processing video 848/877: 863
# Extracting features from 50 images in /tmp/xirl/datasets/xmagical/train/mediumstick/773...
# Finished processing video 849/877: 773
# Extracting features from 108 images in /tmp/xirl/datasets/xmagical/train/mediumstick/121...
# Finished processing video 850/877: 121
# Extracting features from 36 images in /tmp/xirl/datasets/xmagical/train/mediumstick/726...
# Finished processing video 851/877: 726
# Extracting features from 48 images in /tmp/xirl/datasets/xmagical/train/mediumstick/705...
# Finished processing video 852/877: 705
# Extracting features from 52 images in /tmp/xirl/datasets/xmagical/train/mediumstick/102...
# Finished processing video 853/877: 102
# Extracting features from 35 images in /tmp/xirl/datasets/xmagical/train/mediumstick/771...
# Finished processing video 854/877: 771
# Extracting features from 57 images in /tmp/xirl/datasets/xmagical/train/mediumstick/86...
# Finished processing video 855/877: 86
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/mediumstick/961...
# Finished processing video 856/877: 961
# Extracting features from 65 images in /tmp/xirl/datasets/xmagical/train/mediumstick/130...
# Finished processing video 857/877: 130
# Extracting features from 56 images in /tmp/xirl/datasets/xmagical/train/mediumstick/563...
# Finished processing video 858/877: 563
# Extracting features from 72 images in /tmp/xirl/datasets/xmagical/train/mediumstick/87...
# Finished processing video 859/877: 87
# Extracting features from 153 images in /tmp/xirl/datasets/xmagical/train/mediumstick/235...
# Finished processing video 860/877: 235
# Extracting features from 76 images in /tmp/xirl/datasets/xmagical/train/mediumstick/905...

# %%
# Connect images between videos using k-NN
edges_between_videos = connect_videos_with_knn(all_graphs)

# Combine all graphs into one large graph
combined_features = np.vstack([graph[0] for graph in all_graphs])  # Combine feature vectors
combined_node_source = []
combined_node_target = []
combined_edge_attr = []

# Add edges from individual videos to combined graph
for idx, (features, node_source, node_target, edge_attr) in enumerate(all_graphs):
    offset = sum([graph[0].shape[0] for graph in all_graphs[:idx]])  # Calculate offset for current video
    combined_node_source.extend([source + offset for source in node_source])
    combined_node_target.extend([target + offset for target in node_target])
    combined_edge_attr.extend(edge_attr)

# Add inter-video edges to combined graph
combined_node_source.extend([source for source, _ in edges_between_videos])
combined_node_target.extend([target for _, target in edges_between_videos])

# Create final graph data object with combined data
final_graph_data = Data(
    x=torch.tensor(combined_features, dtype=torch.float32),
    edge_index=torch.tensor([combined_node_source, combined_node_target], dtype=torch.long),
)

# Save the final combined graph data
torch.save(final_graph_data, os.path.join(output_graphs_path, 'combined_graph.pt'))

print('Combined graph generation completed and saved as combined_graph.pt.')
