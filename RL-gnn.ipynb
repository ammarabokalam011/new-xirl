# %%
import os.path as osp
import subprocess
import os
from configs.constants import XMAGICAL_EMBODIMENT_TO_ENV_NAME

from absl import app
from absl import logging
from configs.constants import ALGORITHMS
from configs.constants import EMBODIMENTS
from torchkit.experiment import string_from_kwargs
from torchkit.experiment import unique_id
import yaml
import random
# Out:
# 2024-11-26 20:27:02.514781: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 20:27:02.514868: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 20:27:02.514889: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-26 20:27:02.527311: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
seeds = [0, 5]
device = "cuda:0"

experiment_name = '/home/user/xirl/exp/same_long_gnn/'
embodiment = 'longstick'

with open(osp.join(experiment_name, "config.yaml"), "r") as fp:
    kwargs = yaml.load(fp, Loader=yaml.FullLoader)

if kwargs["algorithm"] == "goal_classifier":
    reward_type = "goal_classifier"
else:
    reward_type = "distance_to_goal"

# Map the embodiment to the x-MAGICAL env name.
env_name = XMAGICAL_EMBODIMENT_TO_ENV_NAME[embodiment]

logging.info("Experiment name: %s", experiment_name)

# %%
# Execute each seed in parallel.
procs = []
for seed in range(*list(map(int, seeds))):
    procs.append(
        subprocess.Popen([  # pylint: disable=consider-using-with
            "python",
            "train_policy_gnn.py",
            "--experiment_name",
            experiment_name,
            "--env_name",
            f"{env_name}",
            "--config",
            f"configs/xmagical/rl/env_reward.py:{embodiment}",
            "--config.reward_wrapper.pretrained_path",
            f"{experiment_name}",
            "--config.reward_wrapper.type",
            f"{reward_type}",
            "--seed",
            f"{seed}",
            "--device",
            f"{device}",
            '--resume',
        ]))

# Wait for each seed to terminate.
for p in procs:
    p.wait()
# Out:
# 2024-11-26 20:27:19.768186: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 20:27:19.768255: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 20:27:19.768277: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-26 20:27:19.823514: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-26 20:27:20.513351: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 20:27:20.515288: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 20:27:20.515429: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-26 20:27:20.545994: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-26 20:27:20.654521: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 20:27:20.654792: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 20:27:20.654925: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-26 20:27:20.681622: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-26 20:27:20.918432: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 20:27:20.921234: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 20:27:20.921261: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-26 20:27:20.939799: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-26 20:27:20.988495: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 20:27:20.989105: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 20:27:20.989516: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-26 20:27:21.010856: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-26 20:27:36.536325: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:36.665287: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:36.666511: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I1126 20:27:36.684592 124201781991232 train_policy_gnn.py:102] Using device: cuda:0
# I1126 20:27:36.685116 124201781991232 train_policy_gnn.py:106] RL experiment seed: 3
# 2024-11-26 20:27:37.165327: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:37.293756: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:37.308664: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:37.314775: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:37.315539: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I1126 20:27:37.342732 123465493583680 train_policy_gnn.py:102] Using device: cuda:0
# I1126 20:27:37.343389 123465493583680 train_policy_gnn.py:106] RL experiment seed: 2
# 2024-11-26 20:27:37.433120: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:37.433955: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:37.439316: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:37.443508: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:37.443721: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I1126 20:27:37.454956 135284192995136 train_policy_gnn.py:102] Using device: cuda:0
# I1126 20:27:37.455752 135284192995136 train_policy_gnn.py:106] RL experiment seed: 1
# I1126 20:27:37.474821 138720457398080 train_policy_gnn.py:102] Using device: cuda:0
# I1126 20:27:37.475442 138720457398080 train_policy_gnn.py:106] RL experiment seed: 0
# 2024-11-26 20:27:37.578846: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-26 20:27:37.580954: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I1126 20:27:37.600247 123931579619136 train_policy_gnn.py:102] Using device: cuda:0
# I1126 20:27:37.604267 123931579619136 train_policy_gnn.py:106] RL experiment seed: 4
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# W1126 20:27:41.037518 124201781991232 checkpoint.py:108] optimizer in saved checkpoint not in checkpoint to reload. Skipping it.
# I1126 20:27:41.084982 124201781991232 utils.py:114] Restored model from checkpoint 4001.
# I1126 20:27:41.087513 124201781991232 utils.py:131] Successfully loaded gnn_emb.pkl from /home/user/xirl/exp/same_long_gnn/gnn_emb.pkl
# I1126 20:27:41.090305 124201781991232 utils.py:131] Successfully loaded gnn_distance_scale.pkl from /home/user/xirl/exp/same_long_gnn/gnn_distance_scale.pkl
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
#   0%|          | 0/75000 [00:00<?, ?it/s]/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading chipmunk for Linux (64bit) [/home/user/mambaforge/envs/env/lib/python3.11/site-packages/pymunk/libchipmunk.so]
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
#   0%|          | 48/75000 [00:01<31:23, 39.79it/s]W1126 20:27:42.497077 123931579619136 checkpoint.py:108] optimizer in saved checkpoint not in checkpoint to reload. Skipping it.
# I1126 20:27:42.533372 123931579619136 utils.py:114] Restored model from checkpoint 4001.
# I1126 20:27:42.533928 123931579619136 utils.py:131] Successfully loaded gnn_emb.pkl from /home/user/xirl/exp/same_long_gnn/gnn_emb.pkl
# I1126 20:27:42.534069 123931579619136 utils.py:131] Successfully loaded gnn_distance_scale.pkl from /home/user/xirl/exp/same_long_gnn/gnn_distance_scale.pkl
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# W1126 20:27:42.566832 123465493583680 checkpoint.py:108] optimizer in saved checkpoint not in checkpoint to reload. Skipping it.
#   0%|          | 53/75000 [00:01<31:37, 39.49it/s]W1126 20:27:42.598835 135284192995136 checkpoint.py:108] optimizer in saved checkpoint not in checkpoint to reload. Skipping it.
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
#   0%|          | 0/75000 [00:00<?, ?it/s]I1126 20:27:42.618360 123465493583680 utils.py:114] Restored model from checkpoint 4001.
# I1126 20:27:42.618797 123465493583680 utils.py:131] Successfully loaded gnn_emb.pkl from /home/user/xirl/exp/same_long_gnn/gnn_emb.pkl
# I1126 20:27:42.618937 123465493583680 utils.py:131] Successfully loaded gnn_distance_scale.pkl from /home/user/xirl/exp/same_long_gnn/gnn_distance_scale.pkl
# W1126 20:27:42.620961 138720457398080 checkpoint.py:108] optimizer in saved checkpoint not in checkpoint to reload. Skipping it.
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# I1126 20:27:42.633529 135284192995136 utils.py:114] Restored model from checkpoint 4001.
# I1126 20:27:42.633944 135284192995136 utils.py:131] Successfully loaded gnn_emb.pkl from /home/user/xirl/exp/same_long_gnn/gnn_emb.pkl
# I1126 20:27:42.634113 135284192995136 utils.py:131] Successfully loaded gnn_distance_scale.pkl from /home/user/xirl/exp/same_long_gnn/gnn_distance_scale.pkl
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# Loading chipmunk for Linux (64bit) [/home/user/mambaforge/envs/env/lib/python3.11/site-packages/pymunk/libchipmunk.so]
# Loading chipmunk for Linux (64bit) [/home/user/mambaforge/envs/env/lib/python3.11/site-packages/pymunk/libchipmunk.so]
# Loading chipmunk for Linux (64bit) [/home/user/mambaforge/envs/env/lib/python3.11/site-packages/pymunk/libchipmunk.so]
# Loading chipmunk for Linux (64bit) [/home/user/mambaforge/envs/env/lib/python3.11/site-packages/pymunk/libchipmunk.so]
# I1126 20:27:42.673341 138720457398080 utils.py:114] Restored model from checkpoint 4001.
# I1126 20:27:42.674408 138720457398080 utils.py:131] Successfully loaded gnn_emb.pkl from /home/user/xirl/exp/same_long_gnn/gnn_emb.pkl
# I1126 20:27:42.676502 138720457398080 utils.py:131] Successfully loaded gnn_distance_scale.pkl from /home/user/xirl/exp/same_long_gnn/gnn_distance_scale.pkl
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
#   0%|          | 0/75000 [00:00<?, ?it/s]/home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
#   0%|          | 0/75000 [00:00<?, ?it/s]/home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
#   0%|          | 0/75000 [00:00<?, ?it/s]/home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
#   0%|          | 2/75000 [00:00<1:03:42, 19.62it/s]/home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
#  73%|███████▎  | 54999/75000 [1:26:36<31:29, 10.58it/s]
#  73%|███████▎  | 54999/75000 [1:26:36<31:29, 10.58it/s]
#  73%|███████▎  | 54840/75000 [1:26:38<29:33, 11.37it/s]Traceback (most recent call last):
#   File "/home/user/xirl/train_policy_gnn.py", line 203, in main
#     eval_stats = evaluate(policy, eval_env, config.num_eval_episodes)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/train_policy_gnn.py", line 71, in evaluate
#     observation, _, done, info = env.step(action)
#                                  ^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/sac/wrappers.py", line 75, in step
#     obs, reward, done, info = self.env.step(action)
#                               ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/sac/wrappers.py", line 211, in step
#     imageio.mimsave(filename, self.frames, fps=self.fps)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/v2.py", line 494, in mimwrite
#     with imopen(uri, "wI", **imopen_args) as file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/imopen.py", line 113, in imopen
#     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/request.py", line 247, in __init__
#     self._parse_uri(uri)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/request.py", line 412, in _parse_uri
#     raise FileNotFoundError("The directory %r does not exist" % dn)
# FileNotFoundError: The directory '/home/user/xirl/exp/same_long_gnn/2/video/eval' does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/user/xirl/train_policy_gnn.py", line 227, in <module>
#     app.run(main)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#              ^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/utils/pdb_fallback.py", line 58, in inner_wrapper
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/train_policy_gnn.py", line 220, in main
#     checkpoint_manager.save(i)  # pylint: disable=undefined-loop-variable
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py", line 201, in save
#     self.checkpoint.save(save_path)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py", line 84, in save
#     os.rename(tmp_path, save_path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmp36lz4eas/tmp.ckpt' -> '/home/user/xirl/exp/same_long_gnn/2/checkpoints/54999.ckpt'
#  73%|███████▎  | 54842/75000 [1:26:38<30:41, 10.95it/s]Traceback (most recent call last):
#   File "/home/user/xirl/train_policy_gnn.py", line 203, in main
#     eval_stats = evaluate(policy, eval_env, config.num_eval_episodes)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/train_policy_gnn.py", line 71, in evaluate
#     observation, _, done, info = env.step(action)
#                                  ^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/sac/wrappers.py", line 75, in step
#     obs, reward, done, info = self.env.step(action)
#                               ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/sac/wrappers.py", line 211, in step
#     imageio.mimsave(filename, self.frames, fps=self.fps)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/v2.py", line 494, in mimwrite
#     with imopen(uri, "wI", **imopen_args) as file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/imopen.py", line 113, in imopen
#     request = Request(uri, io_mode, f
# > /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py(84)save()
# -> os.rename(tmp_path, save_path)
# (Pdb)
# > /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py(84)save()
# -> os.rename(tmp_path, save_path)
# (Pdb)
# ormat_hint=format_hint, extension=extension)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/request.py", line 247, in __init__
#     self._parse_uri(uri)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/request.py", line 412, in _parse_uri
#     raise FileNotFoundError("The directory %r does not exist" % dn)
# FileNotFoundError: The directory '/home/user/xirl/exp/same_long_gnn/1/video/eval' does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/user/xirl/train_policy_gnn.py", line 227, in <module>
#     app.run(main)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#              ^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/utils/pdb_fallback.py", line 58, in inner_wrapper
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/train_policy_gnn.py", line 220, in main
#     checkpoint_manager.save(i)  # pylint: disable=undefined-loop-variable
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py", line 201, in save
#     self.checkpoint.save(save_path)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py", line 84, in save
#     os.rename(tmp_path, save_path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpjszzbcwx/tmp.ckpt' -> '/home/user/xirl/exp/same_long_gnn/1/checkpoints/54999.ckpt'
#  73%|███████▎  | 54999/75000 [1:26:37<31:29, 10.58it/s]
#  73%|███████▎  | 54999/75000 [1:26:37<31:29, 10.58it/s]
#  73%|███████▎  | 54848/75000 [1:26:38<32:45, 10.25it/s]Traceback (most recent call last):
#   File "/home/user/xirl/train_policy_gnn.py", line 203, in main
#     eval_stats = evaluate(policy, eval_env, config.num_eval_episodes)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/train_policy_gnn.py", line 71, in evaluate
#     observation, _, done, info = env.step(action)
#                                  ^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/sac/wrappers.py", line 75, in step
#     obs, reward, done, info = self.env.step(action)
#                               ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/sac/wrappers.py", line 211, in step
#     imageio.mimsave(filename, self.frames, fps=self.fps)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/v2.py", line 494, in mimwrite
#     with imopen(uri, "wI", **imopen_args) as file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/imopen.py", line 113, in imopen
#     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/request.py", line 247, in __init__
#     self._parse_uri(uri)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/request.py", line 412, in _parse_uri
#     raise FileNotFoundError("The directory %r does not exist" % dn)
# FileNotFoundError: The directory '/home/user/xirl/exp/same_long_gnn/4/video/eval' does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/user/xirl/train_policy_gnn.py", line 227, in <module>
#     app.run(main)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#              ^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/utils/pdb_fallback.py", line 58, in inner_wrapper
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/train_policy_gnn.py", line 220, in main
#     checkpoint_manager.save(i)  # pylint: disable=undefined-loop-variable
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py", line 201, in save
#     self.checkpoint.save(save_path)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py", line 84, in save
#     os.rename(tmp_path, save_path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpskkyj7k6/tmp.ckpt' -> '/home/user/xirl/exp/same_long_gnn/4/checkpoints/54999.ckpt'
# Traceback (most recent call last):
#   File "/home/user/xirl/train_policy_gnn.py", line 203, in main
#     eval_stats = evaluate(policy, eval_env, config.num_eval_episodes)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/train_policy_gnn.py", line 71, in evaluate
#     observation, _, done, info = env.step(action)
#                                  ^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/sac/wrappers.py", line 75, in step
#     obs, reward, done, info = self.env.step(action)
#                               ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/sac/wrappers.py", line 211, in step
#     imageio.mimsave(filename, self.frames, fps=self.fps)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/v2.py", line 494, in mimwrite
#     with imopen(uri, "wI", **imopen_args) as file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/imopen.py", line 113, in imopen
#     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/request.py", line 247, in __init__
#     self._parse_uri(uri)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/request.py", line 412,
# > /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py(84)save()
# -> os.rename(tmp_path, save_path)
# (Pdb)
# > /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py(84)save()
# -> os.rename(tmp_path, save_path)
# (Pdb)
#  in _parse_uri
#     raise FileNotFoundError("The directory %r does not exist" % dn)
# FileNotFoundError: The directory '/home/user/xirl/exp/same_long_gnn/0/video/eval' does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/user/xirl/train_policy_gnn.py", line 227, in <module>
#     app.run(main)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#              ^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/utils/pdb_fallback.py", line 58, in inner_wrapper
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/train_policy_gnn.py", line 220, in main
#     checkpoint_manager.save(i)  # pylint: disable=undefined-loop-variable
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py", line 201, in save
#     self.checkpoint.save(save_path)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py", line 84, in save
#     os.rename(tmp_path, save_path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpvfqd_ufw/tmp.ckpt' -> '/home/user/xirl/exp/same_long_gnn/0/checkpoints/54999.ckpt'
#  73%|███████▎  | 54999/75000 [1:26:49<31:34, 10.56it/s]
# Traceback (most recent call last):
#   File "/home/user/xirl/train_policy_gnn.py", line 203, in main
#     eval_stats = evaluate(policy, eval_env, config.num_eval_episodes)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/train_policy_gnn.py", line 71, in evaluate
#     observation, _, done, info = env.step(action)
#                                  ^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/sac/wrappers.py", line 75, in step
#     obs, reward, done, info = self.env.step(action)
#                               ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/sac/wrappers.py", line 211, in step
#     imageio.mimsave(filename, self.frames, fps=self.fps)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/v2.py", line 494, in mimwrite
#     with imopen(uri, "wI", **imopen_args) as file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/imopen.py", line 113, in imopen
#     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/request.py", line 247, in __init__
#     self._parse_uri(uri)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/imageio/core/request.py", line 412, in _parse_uri
#     raise FileNotFoundError("The directory %r does not exist" % dn)
# FileNotFoundError: The directory '/home/user/xirl/exp/same_long_gnn/3/video/eval' does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/user/xirl/train_policy_gnn.py", line 227, in <module>
#     app.run(main)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#              ^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/utils/pdb_fallback.py", line 58, in inner_wrapper
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/user/xirl/train_policy_gnn.py", line 220, in main
#     checkpoint_manager.save(i)  # pylint: disable=undefined-loop-variable
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py", line 201, in save
#     self.checkpoint.save(save_path)
#   File "/home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py", line 84, in save
#     os.rename(tmp_path, save_path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmpir9onm79/tmp.ckpt' -> '/home/user/xirl/exp/same_long_gnn/3/checkpoints/54999.ckpt'
# > /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchkit/checkpoint.py(84)save()
# -> os.rename(tmp_path, save_path)
# (Pdb)
