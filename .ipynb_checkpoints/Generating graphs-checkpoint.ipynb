# %%
import os
import glob
import torch
import argparse
import numpy as np
from functools import partial
from multiprocessing import Pool
from torch_geometric.data import Data
from PIL import Image
from torchvision import models, transforms
# Out:
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: libcudart.so.11.0: cannot open shared object file: No such file or directory
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
# def extract_features(image_path):
#     # Load the pre-trained ResNet model
#     resnet = models.resnet50(pretrained=True)
    
#     # Remove the final classification layer
#     modules = list(resnet.children())[:-1]
#     resnet = torch.nn.Sequential(*modules)

#     # Set the model to evaluation mode
#     resnet.eval()

#     # Define the image transformation
#     preprocess = transforms.Compose([
#         transforms.Resize(256),
#         transforms.CenterCrop(224),
#         transforms.ToTensor(),
#         transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
#     ])

#     # Load and preprocess the image
#     img = Image.open(image_path).convert('RGB')
#     img_tensor = preprocess(img).unsqueeze(0)  # Add batch dimension

#     # Extract features
#     with torch.no_grad():
#         features = resnet(img_tensor)

#     # Flatten the features to get a 1D feature vector
#     features_vector = features.view(features.size(0), -1)

#     return features_vector.numpy()  # Convert to numpy array if needed

# %%
# def get_edge_info(num_frame):
#     skip = skip_factor
#     node_source = []
#     node_target = []
#     edge_attr = []
#     for i in range(num_frame):
#         for j in range(num_frame):
#             frame_diff = i - j
#             if abs(frame_diff) <= tauf:
#                 node_source.append(i)
#                 node_target.append(j)
#                 edge_attr.append(np.sign(frame_diff))
#             elif skip:
#                 if (frame_diff % skip == 0) and (abs(frame_diff) <= skip * tauf):
#                     node_source.append(i)
#                     node_target.append(j)
#                     edge_attr.append(np.sign(frame_diff))
#     return node_source, node_target, edge_attr

# %%
# def generate_temporal_graph(image_folder, path_graphs, video_id):
#     image_files = sorted(glob.glob(os.path.join(image_folder, '*.png')))
#     num_frame = len(image_files)

#     features = []
#     for img_file in image_files:
#         img = Image.open(img_file).convert('RGB')
#         img = np.array(img) / 255.0  # Normalize pixel values to [0, 1]
#         features.append(img.flatten())  # Flatten the image into a feature vector

#     features = np.array(features)

#     # Get edge information
#     node_source, node_target, edge_attr = get_edge_info(num_frame)

#     # Create graph data object
#     graphs = Data(
#         x=torch.tensor(features, dtype=torch.float32),
#         edge_index=torch.tensor([node_source, node_target], dtype=torch.long),
#         edge_attr=torch.tensor(edge_attr, dtype=torch.float32),
#         g=video_id  # Global ID for the video
#     )

#     # Save graph data
#     torch.save(graphs, os.path.join(path_graphs, f'{video_id}.pt'))

# %%
# root_data = './data'
# tauf = 5
# skip_factor = 10
# i = 0

# dataset_folder = '/tmp/xirl/datasets/xmagical/train/shortstick'
# output_graphs_path = os.path.join(root_data, 'graphs')
# os.makedirs(output_graphs_path, exist_ok=True)

# # Iterate through each video folder (0/, 1/, etc.)
# for video_folder in os.listdir(dataset_folder):
#     i=i+1
#     print(i,'video:',video_folder)
#     full_video_path = os.path.join(dataset_folder, video_folder)
#     if os.path.isdir(full_video_path):
#         generate_temporal_graph(full_video_path, output_graphs_path, video_folder)

# print('Graph generation completed.')
# Out:
# 1 video: 99
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 16
#      14     full_video_path = os.path.join(dataset_folder, video_folder)
#      15     if os.path.isdir(full_video_path):
# ---> 16         generate_temporal_graph(full_video_path, output_graphs_path, video_folder)
#      18 print('Graph generation completed.')
#
# NameError: name 'generate_temporal_graph' is not defined

# %%
import os
import glob
import numpy as np
import torch
from torch_geometric.data import Data
from torchvision import models, transforms
from PIL import Image
from sklearn.neighbors import NearestNeighbors

def get_edge_info(num_frame):
    skip = skip_factor
    node_source = []
    node_target = []
    edge_attr = []
    for i in range(num_frame):
        for j in range(num_frame):
            frame_diff = i - j
            if abs(frame_diff) <= tauf:
                node_source.append(i)
                node_target.append(j)
                edge_attr.append(np.sign(frame_diff))
            elif skip:
                if (frame_diff % skip == 0) and (abs(frame_diff) <= skip * tauf):
                    node_source.append(i)
                    node_target.append(j)
                    edge_attr.append(np.sign(frame_diff))
    return node_source, node_target, edge_attr

def extract_features(image_path):
    resnet = models.resnet50(pretrained=True)
    modules = list(resnet.children())[:-1]
    resnet = torch.nn.Sequential(*modules)
    resnet.eval()

    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    img = Image.open(image_path).convert('RGB')
    img_tensor = preprocess(img).unsqueeze(0)

    with torch.no_grad():
        features = resnet(img_tensor)

    return features.view(features.size(0), -1).numpy()

def generate_temporal_graph(image_folder):
    image_files = sorted(glob.glob(os.path.join(image_folder, '*.png')))
    num_frame = len(image_files)

    features = []
    
    print(f"Extracting features from {num_frame} images in {image_folder}...")
    
    # Extract features for each image file
    for img_file in image_files:
        feature_vector = extract_features(img_file)
        features.append(feature_vector)

    features = np.array(features).squeeze()

    # Get edge information within the same video
    node_source, node_target, edge_attr = get_edge_info(num_frame)

    return features, node_source, node_target, edge_attr

def connect_videos_with_knn(all_graphs):
    all_features = []
    
    # Collect all features from all videos
    for features, _, _, _ in all_graphs:
        all_features.append(features)
    
    all_features = np.vstack(all_features)  # Combine features from all videos
    
    # Create a k-NN model to find nearest neighbors across videos
    knn_model = NearestNeighbors(n_neighbors=5)  # You can adjust n_neighbors as needed
    knn_model.fit(all_features)

    edges_from_other_videos = []

    # Create edges based on nearest neighbors
    start_index = 0  # To keep track of where each video's features start in the combined array

    print("Connecting images between videos using k-NN...")
    
    for video_index, (video_features, _, _, _) in enumerate(all_graphs):
        num_video_frames = video_features.shape[0]
        
        # Find nearest neighbors for each feature vector in the current video across all videos
        distances, indices = knn_model.kneighbors(video_features)

        for i in range(num_video_frames):
            for neighbor_index in indices[i]:
                # Ensure that we do not connect nodes within the same video
                if neighbor_index // num_video_frames != video_index:
                    edges_from_other_videos.append((start_index + i, neighbor_index))

        start_index += num_video_frames

        print(f"Processed video {video_index + 1}/{len(all_graphs)}: {num_video_frames} frames")

    return edges_from_other_videos

root_data = './data'
tauf = 5
skip_factor = 10

dataset_folder = '/tmp/xirl/datasets/xmagical/train/shortstick'
output_graphs_path = os.path.join(root_data, 'graphs')
os.makedirs(output_graphs_path, exist_ok=True)

all_graphs = []

# Iterate through each video folder (0/, 1/, etc.)
video_folders = os.listdir(dataset_folder)
total_videos = len(video_folders)

for video_index, video_folder in enumerate(video_folders):
    full_video_path = os.path.join(dataset_folder, video_folder)
    
    if os.path.isdir(full_video_path):
        features, node_source, node_target, edge_attr = generate_temporal_graph(full_video_path)
        
        # Store graph data as a tuple (features, source nodes, target nodes, edge attributes)
        all_graphs.append((features, node_source, node_target, edge_attr))
        
        print(f"Finished processing video {video_index + 1}/{total_videos}: {video_folder}")

# Connect images between videos using k-NN
edges_between_videos = connect_videos_with_knn(all_graphs)

# Combine all graphs into one large graph
combined_features = np.vstack([graph[0] for graph in all_graphs])  # Combine feature vectors
combined_node_source = []
combined_node_target = []
combined_edge_attr = []

# Add edges from individual videos to combined graph
for idx, (features, node_source, node_target, edge_attr) in enumerate(all_graphs):
    offset = sum([graph[0].shape[0] for graph in all_graphs[:idx]])  # Calculate offset for current video
    combined_node_source.extend([source + offset for source in node_source])
    combined_node_target.extend([target + offset for target in node_target])
    combined_edge_attr.extend(edge_attr)

# Add inter-video edges to combined graph
combined_node_source.extend([source for source, _ in edges_between_videos])
combined_node_target.extend([target for _, target in edges_between_videos])

# Create final graph data object with combined data
final_graph_data = Data(
    x=torch.tensor(combined_features, dtype=torch.float32),
    edge_index=torch.tensor([combined_node_source, combined_node_target], dtype=torch.long),
)

# Save the final combined graph data
torch.save(final_graph_data, os.path.join(output_graphs_path, 'combined_graph.pt'))

print('Combined graph generation completed and saved as combined_graph.pt.')
# Out:
# Extracting features from 80 images in /tmp/xirl/datasets/xmagical/train/shortstick/99...
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/user/mambaforge/envs/env/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Finished processing video 1/877: 99
# Extracting features from 47 images in /tmp/xirl/datasets/xmagical/train/shortstick/448...
# Finished processing video 2/877: 448
# Extracting features from 119 images in /tmp/xirl/datasets/xmagical/train/shortstick/420...
# Finished processing video 3/877: 420
# Extracting features from 83 images in /tmp/xirl/datasets/xmagical/train/shortstick/868...
# Finished processing video 4/877: 868
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/465...
# Finished processing video 5/877: 465
# Extracting features from 77 images in /tmp/xirl/datasets/xmagical/train/shortstick/136...
# Finished processing video 6/877: 136
# Extracting features from 76 images in /tmp/xirl/datasets/xmagical/train/shortstick/323...
# Finished processing video 7/877: 323
# Extracting features from 87 images in /tmp/xirl/datasets/xmagical/train/shortstick/683...
# Finished processing video 8/877: 683
# Extracting features from 81 images in /tmp/xirl/datasets/xmagical/train/shortstick/416...
# Finished processing video 9/877: 416
# Extracting features from 38 images in /tmp/xirl/datasets/xmagical/train/shortstick/421...
# Finished processing video 10/877: 421
# Extracting features from 39 images in /tmp/xirl/datasets/xmagical/train/shortstick/127...
# Finished processing video 11/877: 127
# Extracting features from 91 images in /tmp/xirl/datasets/xmagical/train/shortstick/604...
# Finished processing video 12/877: 604
# Extracting features from 106 images in /tmp/xirl/datasets/xmagical/train/shortstick/216...
# Finished processing video 13/877: 216
# Extracting features from 153 images in /tmp/xirl/datasets/xmagical/train/shortstick/808...
# Finished processing video 14/877: 808
# Extracting features from 34 images in /tmp/xirl/datasets/xmagical/train/shortstick/279...
# Finished processing video 15/877: 279
# Extracting features from 44 images in /tmp/xirl/datasets/xmagical/train/shortstick/991...
# Finished processing video 16/877: 991
# Extracting features from 80 images in /tmp/xirl/datasets/xmagical/train/shortstick/243...
# Finished processing video 17/877: 243
# Extracting features from 52 images in /tmp/xirl/datasets/xmagical/train/shortstick/75...
# Finished processing video 18/877: 75
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/930...
# Finished processing video 19/877: 930
# Extracting features from 105 images in /tmp/xirl/datasets/xmagical/train/shortstick/525...
# Finished processing video 20/877: 525
# Extracting features from 71 images in /tmp/xirl/datasets/xmagical/train/shortstick/97...
# Finished processing video 21/877: 97
# Extracting features from 104 images in /tmp/xirl/datasets/xmagical/train/shortstick/654...
# Finished processing video 22/877: 654
# Extracting features from 85 images in /tmp/xirl/datasets/xmagical/train/shortstick/730...
# Finished processing video 23/877: 730
# Extracting features from 48 images in /tmp/xirl/datasets/xmagical/train/shortstick/83...
# Finished processing video 24/877: 83
# Extracting features from 44 images in /tmp/xirl/datasets/xmagical/train/shortstick/867...
# Finished processing video 25/877: 867
# Extracting features from 60 images in /tmp/xirl/datasets/xmagical/train/shortstick/544...
# Finished processing video 26/877: 544
# Extracting features from 62 images in /tmp/xirl/datasets/xmagical/train/shortstick/70...
# Finished processing video 27/877: 70
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/866...
# Finished processing video 28/877: 866
# Extracting features from 112 images in /tmp/xirl/datasets/xmagical/train/shortstick/734...
# Finished processing video 29/877: 734
# Extracting features from 93 images in /tmp/xirl/datasets/xmagical/train/shortstick/374...
# Finished processing video 30/877: 374
# Extracting features from 84 images in /tmp/xirl/datasets/xmagical/train/shortstick/887...
# Finished processing video 31/877: 887
# Extracting features from 80 images in /tmp/xirl/datasets/xmagical/train/shortstick/410...
# Finished processing video 32/877: 410
# Extracting features from 68 images in /tmp/xirl/datasets/xmagical/train/shortstick/546...
# Finished processing video 33/877: 546
# Extracting features from 77 images in /tmp/xirl/datasets/xmagical/train/shortstick/879...
# Finished processing video 34/877: 879
# Extracting features from 81 images in /tmp/xirl/datasets/xmagical/train/shortstick/500...
# Finished processing video 35/877: 500
# Extracting features from 127 images in /tmp/xirl/datasets/xmagical/train/shortstick/511...
# Finished processing video 36/877: 511
# Extracting features from 57 images in /tmp/xirl/datasets/xmagical/train/shortstick/841...
# Finished processing video 37/877: 841
# Extracting features from 103 images in /tmp/xirl/datasets/xmagical/train/shortstick/799...
# Finished processing video 38/877: 799
# Extracting features from 40 images in /tmp/xirl/datasets/xmagical/train/shortstick/582...
# Finished processing video 39/877: 582
# Extracting features from 50 images in /tmp/xirl/datasets/xmagical/train/shortstick/85...
# Finished processing video 40/877: 85
# Extracting features from 98 images in /tmp/xirl/datasets/xmagical/train/shortstick/167...
# Finished processing video 41/877: 167
# Extracting features from 93 images in /tmp/xirl/datasets/xmagical/train/shortstick/565...
# Finished processing video 42/877: 565
# Extracting features from 74 images in /tmp/xirl/datasets/xmagical/train/shortstick/722...
# Finished processing video 43/877: 722
# Extracting features from 61 images in /tmp/xirl/datasets/xmagical/train/shortstick/832...
# Finished processing video 44/877: 832
# Extracting features from 112 images in /tmp/xirl/datasets/xmagical/train/shortstick/736...
# Finished processing video 45/877: 736
# Extracting features from 165 images in /tmp/xirl/datasets/xmagical/train/shortstick/135...
# Finished processing video 46/877: 135
# Extracting features from 122 images in /tmp/xirl/datasets/xmagical/train/shortstick/491...
# Finished processing video 47/877: 491
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/188...
# Finished processing video 48/877: 188
# Extracting features from 64 images in /tmp/xirl/datasets/xmagical/train/shortstick/575...
# Finished processing video 49/877: 575
# Extracting features from 73 images in /tmp/xirl/datasets/xmagical/train/shortstick/729...
# Finished processing video 50/877: 729
# Extracting features from 79 images in /tmp/xirl/datasets/xmagical/train/shortstick/568...
# Finished processing video 51/877: 568
# Extracting features from 120 images in /tmp/xirl/datasets/xmagical/train/shortstick/315...
# Finished processing video 52/877: 315
# Extracting features from 74 images in /tmp/xirl/datasets/xmagical/train/shortstick/282...
# Finished processing video 53/877: 282
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/195...
# Finished processing video 54/877: 195
# Extracting features from 66 images in /tmp/xirl/datasets/xmagical/train/shortstick/769...
# Finished processing video 55/877: 769
# Extracting features from 42 images in /tmp/xirl/datasets/xmagical/train/shortstick/54...
# Finished processing video 56/877: 54
# Extracting features from 121 images in /tmp/xirl/datasets/xmagical/train/shortstick/768...
# Finished processing video 57/877: 768
# Extracting features from 71 images in /tmp/xirl/datasets/xmagical/train/shortstick/949...
# Finished processing video 58/877: 949
# Extracting features from 86 images in /tmp/xirl/datasets/xmagical/train/shortstick/313...
# Finished processing video 59/877: 313
# Extracting features from 87 images in /tmp/xirl/datasets/xmagical/train/shortstick/508...
# Finished processing video 60/877: 508
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/611...
# Finished processing video 61/877: 611
# Extracting features from 60 images in /tmp/xirl/datasets/xmagical/train/shortstick/131...
# Finished processing video 62/877: 131
# Extracting features from 70 images in /tmp/xirl/datasets/xmagical/train/shortstick/552...
# Finished processing video 63/877: 552
# Extracting features from 93 images in /tmp/xirl/datasets/xmagical/train/shortstick/190...
# Finished processing video 64/877: 190
# Extracting features from 65 images in /tmp/xirl/datasets/xmagical/train/shortstick/179...
# Finished processing video 65/877: 179
# Extracting features from 44 images in /tmp/xirl/datasets/xmagical/train/shortstick/438...
# Finished processing video 66/877: 438
# Extracting features from 46 images in /tmp/xirl/datasets/xmagical/train/shortstick/644...
# Finished processing video 67/877: 644
# Extracting features from 92 images in /tmp/xirl/datasets/xmagical/train/shortstick/378...
# Finished processing video 68/877: 378
# Extracting features from 51 images in /tmp/xirl/datasets/xmagical/train/shortstick/645...
# Finished processing video 69/877: 645
# Extracting features from 54 images in /tmp/xirl/datasets/xmagical/train/shortstick/716...
# Finished processing video 70/877: 716
# Extracting features from 200 images in /tmp/xirl/datasets/xmagical/train/shortstick/506...
# Finished processing video 71/877: 506
# Extracting features from 87 images in /tmp/xirl/datasets/xmagical/train/shortstick/757...
# Finished processing video 72/877: 757
# Extracting features from 60 images in /tmp/xirl/datasets/xmagical/train/shortstick/711...
# Finished processing video 73/877: 711
# Extracting features from 184 images in /tmp/xirl/datasets/xmagical/train/shortstick/430...
# Finished processing video 74/877: 430
# Extracting features from 91 images in /tmp/xirl/datasets/xmagical/train/shortstick/244...
# Finished processing video 75/877: 244
# Extracting features from 174 images in /tmp/xirl/datasets/xmagical/train/shortstick/484...
# Finished processing video 76/877: 484
# Extracting features from 69 images in /tmp/xirl/datasets/xmagical/train/shortstick/493...
# Finished processing video 77/877: 493
# Extracting features from 59 images in /tmp/xirl/datasets/xmagical/train/shortstick/347...
# Finished processing video 78/877: 347
# Extracting features from 119 images in /tmp/xirl/datasets/xmagical/train/shortstick/78...
# Finished processing video 79/877: 78
# Extracting features from 95 images in /tmp/xirl/datasets/xmagical/train/shortstick/64...
# Finished processing video 80/877: 64
# Extracting features from 170 images in /tmp/xirl/datasets/xmagical/train/shortstick/622...
# Finished processing video 81/877: 622
# Extracting features from 38 images in /tmp/xirl/datasets/xmagical/train/shortstick/681...
# Finished processing video 82/877: 681
# Extracting features from 99 images in /tmp/xirl/datasets/xmagical/train/shortstick/232...
# Finished processing video 83/877: 232
# Extracting features from 66 images in /tmp/xirl/datasets/xmagical/train/shortstick/792...
# Finished processing video 84/877: 792
# Extracting features from 184 images in /tmp/xirl/datasets/xmagical/train/shortstick/607...
# Finished processing video 85/877: 607
# Extracting features from 42 images in /tmp/xirl/datasets/xmagical/train/shortstick/919...
# Finished processing video 86/877: 919
# Extracting features from 60 images in /tmp/xirl/datasets/xmagical/train/shortstick/749...
# Finished processing video 87/877: 749
# Extracting features from 48 images in /tmp/xirl/datasets/xmagical/train/shortstick/363...
# Finished processing video 88/877: 363
# Extracting features from 168 images in /tmp/xirl/datasets/xmagical/train/shortstick/664...
# Finished processing video 89/877: 664
# Extracting features from 127 images in /tmp/xirl/datasets/xmagical/train/shortstick/941...
# Finished processing video 90/877: 941
# Extracting features from 89 images in /tmp/xirl/datasets/xmagical/train/shortstick/837...
# Finished processing video 91/877: 837
# Extracting features from 75 images in /tmp/xirl/datasets/xmagical/train/shortstick/394...
# Finished processing video 92/877: 394
# Extracting features from 58 images in /tmp/xirl/datasets/xmagical/train/shortstick/35...
# Finished processing video 93/877: 35
# Extracting features from 73 images in /tmp/xirl/datasets/xmagical/train/shortstick/566...
# Finished processing video 94/877: 566
# Extracting features from 54 images in /tmp/xirl/datasets/xmagical/train/shortstick/852...
# Finished processing video 95/877: 852
# Extracting features from 50 images in /tmp/xirl/datasets/xmagical/train/shortstick/191...
# Finished processing video 96/877: 191
# Extracting features from 51 images in /tmp/xirl/datasets/xmagical/train/shortstick/161...
# Finished processing video 97/877: 161
# Extracting features from 75 images in /tmp/xirl/datasets/xmagical/train/shortstick/501...
# Finished processing video 98/877: 501
# Extracting features from 96 images in /tmp/xirl/datasets/xmagical/train/shortstick/53...
# Finished processing video 99/877: 53
# Extracting features from 82 images in /tmp/xirl/datasets/xmagical/train/shortstick/214...
# Finished processing video 100/877: 214
# Extracting features from 59 images in /tmp/xirl/datasets/xmagical/train/shortstick/407...
# Finished processing video 101/877: 407
# Extracting features from 139 images in /tmp/xirl/datasets/xmagical/train/shortstick/117...
# Finished processing video 102/877: 117
# Extracting features from 45 images in /tmp/xirl/datasets/xmagical/train/shortstick/486...
# Finished processing video 103/877: 486
# Extracting features from 110 images in /tmp/xirl/datasets/xmagical/train/shortstick/246...
# Finished processing video 104/877: 246
# Extracting features from 71 images in /tmp/xirl/datasets/xmagical/train/shortstick/365...
# Finished processing video 105/877: 365
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/198...
# Finished processing video 106/877: 198
# Extracting features from 155 images in /tmp/xirl/datasets/xmagical/train/shortstick/573...
# Finished processing video 107/877: 573
# Extracting features from 48 images in /tmp/xirl/datasets/xmagical/train/shortstick/970...
# Finished processing video 108/877: 970
# Extracting features from 39 images in /tmp/xirl/datasets/xmagical/train/shortstick/5...
# Finished processing video 109/877: 5
# Extracting features from 91 images in /tmp/xirl/datasets/xmagical/train/shortstick/112...
# Finished processing video 110/877: 112
# Extracting features from 70 images in /tmp/xirl/datasets/xmagical/train/shortstick/924...
# Finished processing video 111/877: 924
# Extracting features from 71 images in /tmp/xirl/datasets/xmagical/train/shortstick/894...
# Finished processing video 112/877: 894
# Extracting features from 108 images in /tmp/xirl/datasets/xmagical/train/shortstick/199...
# Finished processing video 113/877: 199
# Extracting features from 168 images in /tmp/xirl/datasets/xmagical/train/shortstick/790...
# Finished processing video 114/877: 790
# Extracting features from 82 images in /tmp/xirl/datasets/xmagical/train/shortstick/255...
# Finished processing video 115/877: 255
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/763...
# Finished processing video 116/877: 763
# Extracting features from 44 images in /tmp/xirl/datasets/xmagical/train/shortstick/772...
# Finished processing video 117/877: 772
# Extracting features from 79 images in /tmp/xirl/datasets/xmagical/train/shortstick/25...
# Finished processing video 118/877: 25
# Extracting features from 120 images in /tmp/xirl/datasets/xmagical/train/shortstick/974...
# Finished processing video 119/877: 974
# Extracting features from 45 images in /tmp/xirl/datasets/xmagical/train/shortstick/875...
# Finished processing video 120/877: 875
# Extracting features from 76 images in /tmp/xirl/datasets/xmagical/train/shortstick/636...
# Finished processing video 121/877: 636
# Extracting features from 77 images in /tmp/xirl/datasets/xmagical/train/shortstick/660...
# Finished processing video 122/877: 660
# Extracting features from 73 images in /tmp/xirl/datasets/xmagical/train/shortstick/707...
# Finished processing video 123/877: 707
# Extracting features from 53 images in /tmp/xirl/datasets/xmagical/train/shortstick/524...
# Finished processing video 124/877: 524
# Extracting features from 123 images in /tmp/xirl/datasets/xmagical/train/shortstick/335...
# Finished processing video 125/877: 335
# Extracting features from 91 images in /tmp/xirl/datasets/xmagical/train/shortstick/66...
# Finished processing video 126/877: 66
# Extracting features from 68 images in /tmp/xirl/datasets/xmagical/train/shortstick/433...
# Finished processing video 127/877: 433
# Extracting features from 80 images in /tmp/xirl/datasets/xmagical/train/shortstick/105...
# Finished processing video 128/877: 105
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/92...
# Finished processing video 129/877: 92
# Extracting features from 83 images in /tmp/xirl/datasets/xmagical/train/shortstick/639...
# Finished processing video 130/877: 639
# Extracting features from 85 images in /tmp/xirl/datasets/xmagical/train/shortstick/522...
# Finished processing video 131/877: 522
# Extracting features from 54 images in /tmp/xirl/datasets/xmagical/train/shortstick/20...
# Finished processing video 132/877: 20
# Extracting features from 87 images in /tmp/xirl/datasets/xmagical/train/shortstick/786...
# Finished processing video 133/877: 786
# Extracting features from 75 images in /tmp/xirl/datasets/xmagical/train/shortstick/567...
# Finished processing video 134/877: 567
# Extracting features from 89 images in /tmp/xirl/datasets/xmagical/train/shortstick/29...
# Finished processing video 135/877: 29
# Extracting features from 98 images in /tmp/xirl/datasets/xmagical/train/shortstick/337...
# Finished processing video 136/877: 337
# Extracting features from 101 images in /tmp/xirl/datasets/xmagical/train/shortstick/62...
# Finished processing video 137/877: 62
# Extracting features from 89 images in /tmp/xirl/datasets/xmagical/train/shortstick/665...
# Finished processing video 138/877: 665
# Extracting features from 124 images in /tmp/xirl/datasets/xmagical/train/shortstick/984...
# Finished processing video 139/877: 984
# Extracting features from 173 images in /tmp/xirl/datasets/xmagical/train/shortstick/338...
# Finished processing video 140/877: 338
# Extracting features from 127 images in /tmp/xirl/datasets/xmagical/train/shortstick/275...
# Finished processing video 141/877: 275
# Extracting features from 55 images in /tmp/xirl/datasets/xmagical/train/shortstick/223...
# Finished processing video 142/877: 223
# Extracting features from 80 images in /tmp/xirl/datasets/xmagical/train/shortstick/132...
# Finished processing video 143/877: 132
# Extracting features from 78 images in /tmp/xirl/datasets/xmagical/train/shortstick/236...
# Finished processing video 144/877: 236
# Extracting features from 148 images in /tmp/xirl/datasets/xmagical/train/shortstick/218...
# Finished processing video 145/877: 218
# Extracting features from 80 images in /tmp/xirl/datasets/xmagical/train/shortstick/144...
# Finished processing video 146/877: 144
# Extracting features from 152 images in /tmp/xirl/datasets/xmagical/train/shortstick/57...
# Finished processing video 147/877: 57
# Extracting features from 165 images in /tmp/xirl/datasets/xmagical/train/shortstick/192...
# Finished processing video 148/877: 192
# Extracting features from 78 images in /tmp/xirl/datasets/xmagical/train/shortstick/870...
# Finished processing video 149/877: 870
# Extracting features from 96 images in /tmp/xirl/datasets/xmagical/train/shortstick/520...
# Finished processing video 150/877: 520
# Extracting features from 96 images in /tmp/xirl/datasets/xmagical/train/shortstick/450...
# Finished processing video 151/877: 450
# Extracting features from 43 images in /tmp/xirl/datasets/xmagical/train/shortstick/963...
# Finished processing video 152/877: 963
# Extracting features from 78 images in /tmp/xirl/datasets/xmagical/train/shortstick/540...
# Finished processing video 153/877: 540
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/34...
# Finished processing video 154/877: 34
# Extracting features from 89 images in /tmp/xirl/datasets/xmagical/train/shortstick/68...
# Finished processing video 155/877: 68
# Extracting features from 122 images in /tmp/xirl/datasets/xmagical/train/shortstick/351...
# Finished processing video 156/877: 351
# Extracting features from 96 images in /tmp/xirl/datasets/xmagical/train/shortstick/618...
# Finished processing video 157/877: 618
# Extracting features from 79 images in /tmp/xirl/datasets/xmagical/train/shortstick/343...
# Finished processing video 158/877: 343
# Extracting features from 74 images in /tmp/xirl/datasets/xmagical/train/shortstick/177...
# Finished processing video 159/877: 177
# Extracting features from 61 images in /tmp/xirl/datasets/xmagical/train/shortstick/783...
# Finished processing video 160/877: 783
# Extracting features from 52 images in /tmp/xirl/datasets/xmagical/train/shortstick/273...
# Finished processing video 161/877: 273
# Extracting features from 57 images in /tmp/xirl/datasets/xmagical/train/shortstick/61...
# Finished processing video 162/877: 61
# Extracting features from 78 images in /tmp/xirl/datasets/xmagical/train/shortstick/261...
# Finished processing video 163/877: 261
# Extracting features from 95 images in /tmp/xirl/datasets/xmagical/train/shortstick/263...
# Finished processing video 164/877: 263
# Extracting features from 36 images in /tmp/xirl/datasets/xmagical/train/shortstick/999...
# Finished processing video 165/877: 999
# Extracting features from 45 images in /tmp/xirl/datasets/xmagical/train/shortstick/601...
# Finished processing video 166/877: 601
# Extracting features from 47 images in /tmp/xirl/datasets/xmagical/train/shortstick/659...
# Finished processing video 167/877: 659
# Extracting features from 84 images in /tmp/xirl/datasets/xmagical/train/shortstick/306...
# Finished processing video 168/877: 306
# Extracting features from 117 images in /tmp/xirl/datasets/xmagical/train/shortstick/590...
# Finished processing video 169/877: 590
# Extracting features from 100 images in /tmp/xirl/datasets/xmagical/train/shortstick/966...
# Finished processing video 170/877: 966
# Extracting features from 68 images in /tmp/xirl/datasets/xmagical/train/shortstick/723...
# Finished processing video 171/877: 723
# Extracting features from 109 images in /tmp/xirl/datasets/xmagical/train/shortstick/287...
# Finished processing video 172/877: 287
# Extracting features from 82 images in /tmp/xirl/datasets/xmagical/train/shortstick/708...
# Finished processing video 173/877: 708
# Extracting features from 43 images in /tmp/xirl/datasets/xmagical/train/shortstick/464...
# Finished processing video 174/877: 464
# Extracting features from 35 images in /tmp/xirl/datasets/xmagical/train/shortstick/480...
# Finished processing video 175/877: 480
# Extracting features from 59 images in /tmp/xirl/datasets/xmagical/train/shortstick/600...
# Finished processing video 176/877: 600
# Extracting features from 112 images in /tmp/xirl/datasets/xmagical/train/shortstick/77...
# Finished processing video 177/877: 77
# Extracting features from 65 images in /tmp/xirl/datasets/xmagical/train/shortstick/997...
# Finished processing video 178/877: 997
# Extracting features from 88 images in /tmp/xirl/datasets/xmagical/train/shortstick/950...
# Finished processing video 179/877: 950
# Extracting features from 72 images in /tmp/xirl/datasets/xmagical/train/shortstick/24...
# Finished processing video 180/877: 24
# Extracting features from 87 images in /tmp/xirl/datasets/xmagical/train/shortstick/300...
# Finished processing video 181/877: 300
# Extracting features from 68 images in /tmp/xirl/datasets/xmagical/train/shortstick/227...
# Finished processing video 182/877: 227
# Extracting features from 104 images in /tmp/xirl/datasets/xmagical/train/shortstick/385...
# Finished processing video 183/877: 385
# Extracting features from 105 images in /tmp/xirl/datasets/xmagical/train/shortstick/460...
# Finished processing video 184/877: 460
# Extracting features from 44 images in /tmp/xirl/datasets/xmagical/train/shortstick/321...
# Finished processing video 185/877: 321
# Extracting features from 54 images in /tmp/xirl/datasets/xmagical/train/shortstick/698...
# Finished processing video 186/877: 698
# Extracting features from 38 images in /tmp/xirl/datasets/xmagical/train/shortstick/16...
# Finished processing video 187/877: 16
# Extracting features from 75 images in /tmp/xirl/datasets/xmagical/train/shortstick/23...
# Finished processing video 188/877: 23
# Extracting features from 41 images in /tmp/xirl/datasets/xmagical/train/shortstick/487...
# Finished processing video 189/877: 487
# Extracting features from 77 images in /tmp/xirl/datasets/xmagical/train/shortstick/395...
# Finished processing video 190/877: 395
# Extracting features from 41 images in /tmp/xirl/datasets/xmagical/train/shortstick/60...
# Finished processing video 191/877: 60
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/890...
# Finished processing video 192/877: 890
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/43...
# Finished processing video 193/877: 43
# Extracting features from 52 images in /tmp/xirl/datasets/xmagical/train/shortstick/515...
# Finished processing video 194/877: 515
# Extracting features from 70 images in /tmp/xirl/datasets/xmagical/train/shortstick/125...
# Finished processing video 195/877: 125
# Extracting features from 108 images in /tmp/xirl/datasets/xmagical/train/shortstick/960...
# Finished processing video 196/877: 960
# Extracting features from 81 images in /tmp/xirl/datasets/xmagical/train/shortstick/307...
# Finished processing video 197/877: 307
# Extracting features from 74 images in /tmp/xirl/datasets/xmagical/train/shortstick/50...
# Finished processing video 198/877: 50
# Extracting features from 118 images in /tmp/xirl/datasets/xmagical/train/shortstick/238...
# Finished processing video 199/877: 238
# Extracting features from 99 images in /tmp/xirl/datasets/xmagical/train/shortstick/372...
# Finished processing video 200/877: 372
# Extracting features from 55 images in /tmp/xirl/datasets/xmagical/train/shortstick/977...
# Finished processing video 201/877: 977
# Extracting features from 104 images in /tmp/xirl/datasets/xmagical/train/shortstick/844...
# Finished processing video 202/877: 844
# Extracting features from 145 images in /tmp/xirl/datasets/xmagical/train/shortstick/796...
# Finished processing video 203/877: 796
# Extracting features from 96 images in /tmp/xirl/datasets/xmagical/train/shortstick/750...
# Finished processing video 204/877: 750
# Extracting features from 76 images in /tmp/xirl/datasets/xmagical/train/shortstick/990...
# Finished processing video 205/877: 990
# Extracting features from 51 images in /tmp/xirl/datasets/xmagical/train/shortstick/163...
# Finished processing video 206/877: 163
# Extracting features from 138 images in /tmp/xirl/datasets/xmagical/train/shortstick/610...
# Finished processing video 207/877: 610
# Extracting features from 71 images in /tmp/xirl/datasets/xmagical/train/shortstick/355...
# Finished processing video 208/877: 355
# Extracting features from 68 images in /tmp/xirl/datasets/xmagical/train/shortstick/668...
# Finished processing video 209/877: 668
# Extracting features from 83 images in /tmp/xirl/datasets/xmagical/train/shortstick/637...
# Finished processing video 210/877: 637
# Extracting features from 172 images in /tmp/xirl/datasets/xmagical/train/shortstick/538...
# Finished processing video 211/877: 538
# Extracting features from 82 images in /tmp/xirl/datasets/xmagical/train/shortstick/147...
# Finished processing video 212/877: 147
# Extracting features from 76 images in /tmp/xirl/datasets/xmagical/train/shortstick/620...
# Finished processing video 213/877: 620
# Extracting features from 173 images in /tmp/xirl/datasets/xmagical/train/shortstick/591...
# Finished processing video 214/877: 591
# Extracting features from 79 images in /tmp/xirl/datasets/xmagical/train/shortstick/93...
# Finished processing video 215/877: 93
# Extracting features from 82 images in /tmp/xirl/datasets/xmagical/train/shortstick/809...
# Finished processing video 216/877: 809
# Extracting features from 98 images in /tmp/xirl/datasets/xmagical/train/shortstick/333...
# Finished processing video 217/877: 333
# Extracting features from 114 images in /tmp/xirl/datasets/xmagical/train/shortstick/422...
# Finished processing video 218/877: 422
# Extracting features from 98 images in /tmp/xirl/datasets/xmagical/train/shortstick/490...
# Finished processing video 219/877: 490
# Extracting features from 72 images in /tmp/xirl/datasets/xmagical/train/shortstick/598...
# Finished processing video 220/877: 598
# Extracting features from 52 images in /tmp/xirl/datasets/xmagical/train/shortstick/617...
# Finished processing video 221/877: 617
# Extracting features from 106 images in /tmp/xirl/datasets/xmagical/train/shortstick/830...
# Finished processing video 222/877: 830
# Extracting features from 64 images in /tmp/xirl/datasets/xmagical/train/shortstick/693...
# Finished processing video 223/877: 693
# Extracting features from 63 images in /tmp/xirl/datasets/xmagical/train/shortstick/640...
# Finished processing video 224/877: 640
# Extracting features from 76 images in /tmp/xirl/datasets/xmagical/train/shortstick/495...
# Finished processing video 225/877: 495
# Extracting features from 135 images in /tmp/xirl/datasets/xmagical/train/shortstick/541...
# Finished processing video 226/877: 541
# Extracting features from 47 images in /tmp/xirl/datasets/xmagical/train/shortstick/701...
# Finished processing video 227/877: 701
# Extracting features from 52 images in /tmp/xirl/datasets/xmagical/train/shortstick/373...
# Finished processing video 228/877: 373
# Extracting features from 65 images in /tmp/xirl/datasets/xmagical/train/shortstick/73...
# Finished processing video 229/877: 73
# Extracting features from 63 images in /tmp/xirl/datasets/xmagical/train/shortstick/983...
# Finished processing video 230/877: 983
# Extracting features from 72 images in /tmp/xirl/datasets/xmagical/train/shortstick/175...
# Finished processing video 231/877: 175
# Extracting features from 110 images in /tmp/xirl/datasets/xmagical/train/shortstick/119...
# Finished processing video 232/877: 119
# Extracting features from 41 images in /tmp/xirl/datasets/xmagical/train/shortstick/475...
# Finished processing video 233/877: 475
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/27...
# Finished processing video 234/877: 27
# Extracting features from 167 images in /tmp/xirl/datasets/xmagical/train/shortstick/159...
# Finished processing video 235/877: 159
# Extracting features from 75 images in /tmp/xirl/datasets/xmagical/train/shortstick/559...
# Finished processing video 236/877: 559
# Extracting features from 44 images in /tmp/xirl/datasets/xmagical/train/shortstick/843...
# Finished processing video 237/877: 843
# Extracting features from 75 images in /tmp/xirl/datasets/xmagical/train/shortstick/584...
# Finished processing video 238/877: 584
# Extracting features from 93 images in /tmp/xirl/datasets/xmagical/train/shortstick/519...
# Finished processing video 239/877: 519
# Extracting features from 85 images in /tmp/xirl/datasets/xmagical/train/shortstick/651...
# Finished processing video 240/877: 651
# Extracting features from 39 images in /tmp/xirl/datasets/xmagical/train/shortstick/842...
# Finished processing video 241/877: 842
# Extracting features from 83 images in /tmp/xirl/datasets/xmagical/train/shortstick/996...
# Finished processing video 242/877: 996
# Extracting features from 160 images in /tmp/xirl/datasets/xmagical/train/shortstick/148...
# Finished processing video 243/877: 148
# Extracting features from 47 images in /tmp/xirl/datasets/xmagical/train/shortstick/732...
# Finished processing video 244/877: 732
# Extracting features from 148 images in /tmp/xirl/datasets/xmagical/train/shortstick/160...
# Finished processing video 245/877: 160
# Extracting features from 60 images in /tmp/xirl/datasets/xmagical/train/shortstick/110...
# Finished processing video 246/877: 110
# Extracting features from 115 images in /tmp/xirl/datasets/xmagical/train/shortstick/143...
# Finished processing video 247/877: 143
# Extracting features from 71 images in /tmp/xirl/datasets/xmagical/train/shortstick/327...
# Finished processing video 248/877: 327
# Extracting features from 73 images in /tmp/xirl/datasets/xmagical/train/shortstick/341...
# Finished processing video 249/877: 341
# Extracting features from 104 images in /tmp/xirl/datasets/xmagical/train/shortstick/706...
# Finished processing video 250/877: 706
# Extracting features from 69 images in /tmp/xirl/datasets/xmagical/train/shortstick/447...
# Finished processing video 251/877: 447
# Extracting features from 199 images in /tmp/xirl/datasets/xmagical/train/shortstick/922...
# Finished processing video 252/877: 922
# Extracting features from 75 images in /tmp/xirl/datasets/xmagical/train/shortstick/621...
# Finished processing video 253/877: 621
# Extracting features from 73 images in /tmp/xirl/datasets/xmagical/train/shortstick/6...
# Finished processing video 254/877: 6
# Extracting features from 44 images in /tmp/xirl/datasets/xmagical/train/shortstick/72...
# Finished processing video 255/877: 72
# Extracting features from 111 images in /tmp/xirl/datasets/xmagical/train/shortstick/684...
# Finished processing video 256/877: 684
# Extracting features from 92 images in /tmp/xirl/datasets/xmagical/train/shortstick/638...
# Finished processing video 257/877: 638
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/855...
# Finished processing video 258/877: 855
# Extracting features from 142 images in /tmp/xirl/datasets/xmagical/train/shortstick/118...
# Finished processing video 259/877: 118
# Extracting features from 94 images in /tmp/xirl/datasets/xmagical/train/shortstick/375...
# Finished processing video 260/877: 375
# Extracting features from 162 images in /tmp/xirl/datasets/xmagical/train/shortstick/36...
# Finished processing video 261/877: 36
# Extracting features from 84 images in /tmp/xirl/datasets/xmagical/train/shortstick/927...
# Finished processing video 262/877: 927
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/390...
# Finished processing video 263/877: 390
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/532...
# Finished processing video 264/877: 532
# Extracting features from 77 images in /tmp/xirl/datasets/xmagical/train/shortstick/155...
# Finished processing video 265/877: 155
# Extracting features from 50 images in /tmp/xirl/datasets/xmagical/train/shortstick/918...
# Finished processing video 266/877: 918
# Extracting features from 81 images in /tmp/xirl/datasets/xmagical/train/shortstick/656...
# Finished processing video 267/877: 656
# Extracting features from 69 images in /tmp/xirl/datasets/xmagical/train/shortstick/436...
# Finished processing video 268/877: 436
# Extracting features from 38 images in /tmp/xirl/datasets/xmagical/train/shortstick/168...
# Finished processing video 269/877: 168
# Extracting features from 41 images in /tmp/xirl/datasets/xmagical/train/shortstick/973...
# Finished processing video 270/877: 973
# Extracting features from 55 images in /tmp/xirl/datasets/xmagical/train/shortstick/91...
# Finished processing video 271/877: 91
# Extracting features from 41 images in /tmp/xirl/datasets/xmagical/train/shortstick/988...
# Finished processing video 272/877: 988
# Extracting features from 46 images in /tmp/xirl/datasets/xmagical/train/shortstick/521...
# Finished processing video 273/877: 521
# Extracting features from 61 images in /tmp/xirl/datasets/xmagical/train/shortstick/893...
# Finished processing video 274/877: 893
# Extracting features from 60 images in /tmp/xirl/datasets/xmagical/train/shortstick/479...
# Finished processing video 275/877: 479
# Extracting features from 56 images in /tmp/xirl/datasets/xmagical/train/shortstick/858...
# Finished processing video 276/877: 858
# Extracting features from 115 images in /tmp/xirl/datasets/xmagical/train/shortstick/446...
# Finished processing video 277/877: 446
# Extracting features from 65 images in /tmp/xirl/datasets/xmagical/train/shortstick/208...
# Finished processing video 278/877: 208
# Extracting features from 82 images in /tmp/xirl/datasets/xmagical/train/shortstick/141...
# Finished processing video 279/877: 141
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/700...
# Finished processing video 280/877: 700
# Extracting features from 36 images in /tmp/xirl/datasets/xmagical/train/shortstick/418...
# Finished processing video 281/877: 418
# Extracting features from 85 images in /tmp/xirl/datasets/xmagical/train/shortstick/425...
# Finished processing video 282/877: 425
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/468...
# Finished processing video 283/877: 468
# Extracting features from 72 images in /tmp/xirl/datasets/xmagical/train/shortstick/14...
# Finished processing video 284/877: 14
# Extracting features from 93 images in /tmp/xirl/datasets/xmagical/train/shortstick/12...
# Finished processing video 285/877: 12
# Extracting features from 72 images in /tmp/xirl/datasets/xmagical/train/shortstick/972...
# Finished processing video 286/877: 972
# Extracting features from 75 images in /tmp/xirl/datasets/xmagical/train/shortstick/469...
# Finished processing video 287/877: 469
# Extracting features from 76 images in /tmp/xirl/datasets/xmagical/train/shortstick/452...
# Finished processing video 288/877: 452
# Extracting features from 104 images in /tmp/xirl/datasets/xmagical/train/shortstick/413...
# Finished processing video 289/877: 413
# Extracting features from 99 images in /tmp/xirl/datasets/xmagical/train/shortstick/4...
# Finished processing video 290/877: 4
# Extracting features from 160 images in /tmp/xirl/datasets/xmagical/train/shortstick/69...
# Finished processing video 291/877: 69
# Extracting features from 76 images in /tmp/xirl/datasets/xmagical/train/shortstick/502...
# Finished processing video 292/877: 502
# Extracting features from 43 images in /tmp/xirl/datasets/xmagical/train/shortstick/954...
# Finished processing video 293/877: 954
# Extracting features from 137 images in /tmp/xirl/datasets/xmagical/train/shortstick/595...
# Finished processing video 294/877: 595
# Extracting features from 37 images in /tmp/xirl/datasets/xmagical/train/shortstick/854...
# Finished processing video 295/877: 854
# Extracting features from 79 images in /tmp/xirl/datasets/xmagical/train/shortstick/807...
# Finished processing video 296/877: 807
# Extracting features from 57 images in /tmp/xirl/datasets/xmagical/train/shortstick/760...
# Finished processing video 297/877: 760
# Extracting features from 43 images in /tmp/xirl/datasets/xmagical/train/shortstick/823...
# Finished processing video 298/877: 823
# Extracting features from 68 images in /tmp/xirl/datasets/xmagical/train/shortstick/670...
# Finished processing video 299/877: 670
# Extracting features from 78 images in /tmp/xirl/datasets/xmagical/train/shortstick/249...
# Finished processing video 300/877: 249
# Extracting features from 80 images in /tmp/xirl/datasets/xmagical/train/shortstick/915...
# Finished processing video 301/877: 915
# Extracting features from 112 images in /tmp/xirl/datasets/xmagical/train/shortstick/917...
# Finished processing video 302/877: 917
# Extracting features from 73 images in /tmp/xirl/datasets/xmagical/train/shortstick/612...
# Finished processing video 303/877: 612
# Extracting features from 105 images in /tmp/xirl/datasets/xmagical/train/shortstick/289...
# Finished processing video 304/877: 289
# Extracting features from 44 images in /tmp/xirl/datasets/xmagical/train/shortstick/457...
# Finished processing video 305/877: 457
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/377...
# Finished processing video 306/877: 377
# Extracting features from 74 images in /tmp/xirl/datasets/xmagical/train/shortstick/71...
# Finished processing video 307/877: 71
# Extracting features from 104 images in /tmp/xirl/datasets/xmagical/train/shortstick/981...
# Finished processing video 308/877: 981
# Extracting features from 60 images in /tmp/xirl/datasets/xmagical/train/shortstick/445...
# Finished processing video 309/877: 445
# Extracting features from 64 images in /tmp/xirl/datasets/xmagical/train/shortstick/281...
# Finished processing video 310/877: 281
# Extracting features from 156 images in /tmp/xirl/datasets/xmagical/train/shortstick/569...
# Finished processing video 311/877: 569
# Extracting features from 114 images in /tmp/xirl/datasets/xmagical/train/shortstick/186...
# Finished processing video 312/877: 186
# Extracting features from 79 images in /tmp/xirl/datasets/xmagical/train/shortstick/779...
# Finished processing video 313/877: 779
# Extracting features from 55 images in /tmp/xirl/datasets/xmagical/train/shortstick/578...
# Finished processing video 314/877: 578
# Extracting features from 148 images in /tmp/xirl/datasets/xmagical/train/shortstick/173...
# Finished processing video 315/877: 173
# Extracting features from 42 images in /tmp/xirl/datasets/xmagical/train/shortstick/234...
# Finished processing video 316/877: 234
# Extracting features from 43 images in /tmp/xirl/datasets/xmagical/train/shortstick/138...
# Finished processing video 317/877: 138
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/220...
# Finished processing video 318/877: 220
# Extracting features from 96 images in /tmp/xirl/datasets/xmagical/train/shortstick/122...
# Finished processing video 319/877: 122
# Extracting features from 99 images in /tmp/xirl/datasets/xmagical/train/shortstick/862...
# Finished processing video 320/877: 862
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/512...
# Finished processing video 321/877: 512
# Extracting features from 106 images in /tmp/xirl/datasets/xmagical/train/shortstick/942...
# Finished processing video 322/877: 942
# Extracting features from 155 images in /tmp/xirl/datasets/xmagical/train/shortstick/782...
# Finished processing video 323/877: 782
# Extracting features from 90 images in /tmp/xirl/datasets/xmagical/train/shortstick/871...
# Finished processing video 324/877: 871
# Extracting features from 74 images in /tmp/xirl/datasets/xmagical/train/shortstick/758...
# Finished processing video 325/877: 758
# Extracting features from 77 images in /tmp/xirl/datasets/xmagical/train/shortstick/406...
# Finished processing video 326/877: 406
# Extracting features from 42 images in /tmp/xirl/datasets/xmagical/train/shortstick/989...
# Finished processing video 327/877: 989
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/379...
# Finished processing video 328/877: 379
# Extracting features from 43 images in /tmp/xirl/datasets/xmagical/train/shortstick/737...
# Finished processing video 329/877: 737
# Extracting features from 98 images in /tmp/xirl/datasets/xmagical/train/shortstick/886...
# Finished processing video 330/877: 886
# Extracting features from 63 images in /tmp/xirl/datasets/xmagical/train/shortstick/262...
# Finished processing video 331/877: 262
# Extracting features from 190 images in /tmp/xirl/datasets/xmagical/train/shortstick/33...
# Finished processing video 332/877: 33
# Extracting features from 42 images in /tmp/xirl/datasets/xmagical/train/shortstick/776...
# Finished processing video 333/877: 776
# Extracting features from 171 images in /tmp/xirl/datasets/xmagical/train/shortstick/312...
# Finished processing video 334/877: 312
# Extracting features from 128 images in /tmp/xirl/datasets/xmagical/train/shortstick/432...
# Finished processing video 335/877: 432
# Extracting features from 167 images in /tmp/xirl/datasets/xmagical/train/shortstick/761...
# Finished processing video 336/877: 761
# Extracting features from 41 images in /tmp/xirl/datasets/xmagical/train/shortstick/443...
# Finished processing video 337/877: 443
# Extracting features from 49 images in /tmp/xirl/datasets/xmagical/train/shortstick/423...
# Finished processing video 338/877: 423
# Extracting features from 106 images in /tmp/xirl/datasets/xmagical/train/shortstick/240...
# Finished processing video 339/877: 240
# Extracting features from 169 images in /tmp/xirl/datasets/xmagical/train/shortstick/311...
# Finished processing video 340/877: 311
# Extracting features from 81 images in /tmp/xirl/datasets/xmagical/train/shortstick/714...
# Finished processing video 341/877: 714
# Extracting features from 62 images in /tmp/xirl/datasets/xmagical/train/shortstick/685...
# Finished processing video 342/877: 685
# Extracting features from 46 images in /tmp/xirl/datasets/xmagical/train/shortstick/728...
# Finished processing video 343/877: 728
# Extracting features from 121 images in /tmp/xirl/datasets/xmagical/train/shortstick/482...
# Finished processing video 344/877: 482
# Extracting features from 48 images in /tmp/xirl/datasets/xmagical/train/shortstick/114...
# Finished processing video 345/877: 114
# Extracting features from 55 images in /tmp/xirl/datasets/xmagical/train/shortstick/305...
# Finished processing video 346/877: 305
# Extracting features from 50 images in /tmp/xirl/datasets/xmagical/train/shortstick/339...
# Finished processing video 347/877: 339
# Extracting features from 75 images in /tmp/xirl/datasets/xmagical/train/shortstick/481...
# Finished processing video 348/877: 481
# Extracting features from 76 images in /tmp/xirl/datasets/xmagical/train/shortstick/576...
# Finished processing video 349/877: 576
# Extracting features from 70 images in /tmp/xirl/datasets/xmagical/train/shortstick/250...
# Finished processing video 350/877: 250
# Extracting features from 46 images in /tmp/xirl/datasets/xmagical/train/shortstick/393...
# Finished processing video 351/877: 393
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/203...
# Finished processing video 352/877: 203
# Extracting features from 106 images in /tmp/xirl/datasets/xmagical/train/shortstick/814...
# Finished processing video 353/877: 814
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/206...
# Finished processing video 354/877: 206
# Extracting features from 42 images in /tmp/xirl/datasets/xmagical/train/shortstick/788...
# Finished processing video 355/877: 788
# Extracting features from 51 images in /tmp/xirl/datasets/xmagical/train/shortstick/969...
# Finished processing video 356/877: 969
# Extracting features from 44 images in /tmp/xirl/datasets/xmagical/train/shortstick/419...
# Finished processing video 357/877: 419
# Extracting features from 82 images in /tmp/xirl/datasets/xmagical/train/shortstick/834...
# Finished processing video 358/877: 834
# Extracting features from 41 images in /tmp/xirl/datasets/xmagical/train/shortstick/95...
# Finished processing video 359/877: 95
# Extracting features from 95 images in /tmp/xirl/datasets/xmagical/train/shortstick/802...
# Finished processing video 360/877: 802
# Extracting features from 100 images in /tmp/xirl/datasets/xmagical/train/shortstick/804...
# Finished processing video 361/877: 804
# Extracting features from 67 images in /tmp/xirl/datasets/xmagical/train/shortstick/528...
# Finished processing video 362/877: 528
# Extracting features from 53 images in /tmp/xirl/datasets/xmagical/train/shortstick/219...
# Finished processing video 363/877: 219
# Extracting features from 43 images in /tmp/xirl/datasets/xmagical/train/shortstick/777...
# Finished processing video 364/877: 777
# Extracting features from 188 images in /tmp/xirl/datasets/xmagical/train/shortstick/628...
# Finished processing video 365/877: 628
# Extracting features from 41 images in /tmp/xirl/datasets/xmagical/train/shortstick/818...
# Finished processing video 366/877: 818
# Extracting features from 54 images in /tmp/xirl/datasets/xmagical/train/shortstick/517...
# Finished processing video 367/877: 517
# Extracting features from 172 images in /tmp/xirl/datasets/xmagical/train/shortstick/303...
# ...
# Processed video 426/877: 89 frames
# Processed video 427/877: 95 frames
# Processed video 428/877: 92 frames
# Processed video 429/877: 62 frames
# Processed video 430/877: 61 frames
# Processed video 431/877: 52 frames
# Processed video 432/877: 75 frames
# Processed video 433/877: 79 frames
# Processed video 434/877: 66 frames
# Processed video 435/877: 155 frames
# Processed video 436/877: 143 frames
# Processed video 437/877: 157 frames
# Processed video 438/877: 71 frames
# Processed video 439/877: 91 frames
# Processed video 440/877: 115 frames
# Processed video 441/877: 87 frames
# Processed video 442/877: 109 frames
# Processed video 443/877: 45 frames
# Processed video 444/877: 39 frames
# Processed video 445/877: 79 frames
# Processed video 446/877: 66 frames
# Processed video 447/877: 105 frames
# Processed video 448/877: 41 frames
# Processed video 449/877: 100 frames
# Processed video 450/877: 57 frames
# Processed video 451/877: 41 frames
# Processed video 452/877: 37 frames
# Processed video 453/877: 84 frames
# Processed video 454/877: 137 frames
# Processed video 455/877: 95 frames
# Processed video 456/877: 121 frames
# Processed video 457/877: 63 frames
# Processed video 458/877: 103 frames
# Processed video 459/877: 66 frames
# Processed video 460/877: 80 frames
# Processed video 461/877: 60 frames
# Processed video 462/877: 61 frames
# Processed video 463/877: 55 frames
# Processed video 464/877: 93 frames
# Processed video 465/877: 84 frames
# Processed video 466/877: 142 frames
# Processed video 467/877: 49 frames
# Processed video 468/877: 124 frames
# Processed video 469/877: 42 frames
# Processed video 470/877: 44 frames
# Processed video 471/877: 85 frames
# Processed video 472/877: 61 frames
# Processed video 473/877: 74 frames
# Processed video 474/877: 77 frames
# Processed video 475/877: 48 frames
# Processed video 476/877: 86 frames
# Processed video 477/877: 96 frames
# Processed video 478/877: 195 frames
# Processed video 479/877: 131 frames
# Processed video 480/877: 82 frames
# Processed video 481/877: 77 frames
# Processed video 482/877: 81 frames
# Processed video 483/877: 42 frames
# Processed video 484/877: 83 frames
# Processed video 485/877: 99 frames
# Processed video 486/877: 69 frames
# Processed video 487/877: 47 frames
# Processed video 488/877: 177 frames
# Processed video 489/877: 70 frames
# Processed video 490/877: 81 frames
# Processed video 491/877: 94 frames
# Processed video 492/877: 101 frames
# Processed video 493/877: 53 frames
# Processed video 494/877: 75 frames
# Processed video 495/877: 48 frames
# Processed video 496/877: 66 frames
# Processed video 497/877: 167 frames
# Processed video 498/877: 58 frames
# Processed video 499/877: 197 frames
# Processed video 500/877: 51 frames
# Processed video 501/877: 51 frames
# Processed video 502/877: 45 frames
# Processed video 503/877: 108 frames
# Processed video 504/877: 40 frames
# Processed video 505/877: 129 frames
# Processed video 506/877: 60 frames
# Processed video 507/877: 82 frames
# Processed video 508/877: 85 frames
# Processed video 509/877: 82 frames
# Processed video 510/877: 51 frames
# Processed video 511/877: 61 frames
# Processed video 512/877: 68 frames
# Processed video 513/877: 39 frames
# Processed video 514/877: 85 frames
# Processed video 515/877: 63 frames
# Processed video 516/877: 49 frames
# Processed video 517/877: 45 frames
# Processed video 518/877: 77 frames
# Processed video 519/877: 76 frames
# Processed video 520/877: 68 frames
# Processed video 521/877: 54 frames
# Processed video 522/877: 174 frames
# Processed video 523/877: 65 frames
# Processed video 524/877: 87 frames
# Processed video 525/877: 97 frames
# Processed video 526/877: 67 frames
# Processed video 527/877: 43 frames
# Processed video 528/877: 53 frames
# Processed video 529/877: 92 frames
# Processed video 530/877: 83 frames
# Processed video 531/877: 37 frames
# Processed video 532/877: 119 frames
# Processed video 533/877: 89 frames
# Processed video 534/877: 109 frames
# Processed video 535/877: 131 frames
# Processed video 536/877: 85 frames
# Processed video 537/877: 95 frames
# Processed video 538/877: 73 frames
# Processed video 539/877: 79 frames
# Processed video 540/877: 76 frames
# Processed video 541/877: 36 frames
# Processed video 542/877: 44 frames
# Processed video 543/877: 39 frames
# Processed video 544/877: 47 frames
# Processed video 545/877: 47 frames
# Processed video 546/877: 86 frames
# Processed video 547/877: 106 frames
# Processed video 548/877: 74 frames
# Processed video 549/877: 161 frames
# Processed video 550/877: 100 frames
# Processed video 551/877: 116 frames
# Processed video 552/877: 85 frames
# Processed video 553/877: 43 frames
# Processed video 554/877: 71 frames
# Processed video 555/877: 187 frames
# Processed video 556/877: 63 frames
# Processed video 557/877: 114 frames
# Processed video 558/877: 64 frames
# Processed video 559/877: 66 frames
# Processed video 560/877: 157 frames
# Processed video 561/877: 87 frames
# Processed video 562/877: 74 frames
# Processed video 563/877: 59 frames
# Processed video 564/877: 67 frames
# Processed video 565/877: 38 frames
# Processed video 566/877: 78 frames
# Processed video 567/877: 123 frames
# Processed video 568/877: 82 frames
# Processed video 569/877: 105 frames
# Processed video 570/877: 58 frames
# Processed video 571/877: 72 frames
# Processed video 572/877: 63 frames
# Processed video 573/877: 108 frames
# Processed video 574/877: 72 frames
# Processed video 575/877: 38 frames
# Processed video 576/877: 103 frames
# Processed video 577/877: 176 frames
# Processed video 578/877: 69 frames
# Processed video 579/877: 158 frames
# Processed video 580/877: 65 frames
# Processed video 581/877: 61 frames
# Processed video 582/877: 79 frames
# Processed video 583/877: 41 frames
# Processed video 584/877: 119 frames
# Processed video 585/877: 120 frames
# Processed video 586/877: 68 frames
# Processed video 587/877: 81 frames
# Processed video 588/877: 62 frames
# Processed video 589/877: 50 frames
# Processed video 590/877: 52 frames
# Processed video 591/877: 103 frames
# Processed video 592/877: 79 frames
# Processed video 593/877: 81 frames
# Processed video 594/877: 86 frames
# Processed video 595/877: 77 frames
# Processed video 596/877: 46 frames
# Processed video 597/877: 42 frames
# Processed video 598/877: 71 frames
# Processed video 599/877: 69 frames
# Processed video 600/877: 53 frames
# Processed video 601/877: 62 frames
# Processed video 602/877: 133 frames
# Processed video 603/877: 43 frames
# Processed video 604/877: 125 frames
# Processed video 605/877: 54 frames
# Processed video 606/877: 152 frames
# Processed video 607/877: 64 frames
# Processed video 608/877: 99 frames
# Processed video 609/877: 62 frames
# Processed video 610/877: 81 frames
# Processed video 611/877: 70 frames
# Processed video 612/877: 47 frames
# Processed video 613/877: 44 frames
# Processed video 614/877: 41 frames
# Processed video 615/877: 192 frames
# Processed video 616/877: 99 frames
# Processed video 617/877: 84 frames
# Processed video 618/877: 56 frames
# Processed video 619/877: 52 frames
# Processed video 620/877: 84 frames
# Processed video 621/877: 60 frames
# Processed video 622/877: 75 frames
# Processed video 623/877: 37 frames
# Processed video 624/877: 55 frames
# Processed video 625/877: 89 frames
# Processed video 626/877: 46 frames
# Processed video 627/877: 48 frames
# Processed video 628/877: 60 frames
# Processed video 629/877: 39 frames
# Processed video 630/877: 51 frames
# Processed video 631/877: 43 frames
# Processed video 632/877: 112 frames
# Processed video 633/877: 96 frames
# Processed video 634/877: 83 frames
# Processed video 635/877: 93 frames
# Processed video 636/877: 46 frames
# Processed video 637/877: 50 frames
# Processed video 638/877: 76 frames
# Processed video 639/877: 147 frames
# Processed video 640/877: 77 frames
# Processed video 641/877: 45 frames
# Processed video 642/877: 44 frames
# Processed video 643/877: 103 frames
# Processed video 644/877: 60 frames
# Processed video 645/877: 112 frames
# Processed video 646/877: 76 frames
# Processed video 647/877: 87 frames
# Processed video 648/877: 56 frames
# Processed video 649/877: 63 frames
# Processed video 650/877: 140 frames
# Processed video 651/877: 101 frames
# Processed video 652/877: 77 frames
# Processed video 653/877: 141 frames
# Processed video 654/877: 64 frames
# Processed video 655/877: 64 frames
# Processed video 656/877: 90 frames
# Processed video 657/877: 74 frames
# Processed video 658/877: 73 frames
# Processed video 659/877: 60 frames
# Processed video 660/877: 88 frames
# Processed video 661/877: 37 frames
# Processed video 662/877: 43 frames
# Processed video 663/877: 84 frames
# Processed video 664/877: 67 frames
# Processed video 665/877: 66 frames
# Processed video 666/877: 78 frames
# Processed video 667/877: 91 frames
# Processed video 668/877: 95 frames
# Processed video 669/877: 61 frames
# Processed video 670/877: 74 frames
# Processed video 671/877: 52 frames
# Processed video 672/877: 116 frames
# Processed video 673/877: 191 frames
# Processed video 674/877: 163 frames
# Processed video 675/877: 97 frames
# Processed video 676/877: 71 frames
# Processed video 677/877: 82 frames
# Processed video 678/877: 121 frames
# Processed video 679/877: 43 frames
# Processed video 680/877: 40 frames
# Processed video 681/877: 40 frames
# Processed video 682/877: 67 frames
# Processed video 683/877: 63 frames
# Processed video 684/877: 82 frames
# Processed video 685/877: 104 frames
# Processed video 686/877: 73 frames
# Processed video 687/877: 37 frames
# Processed video 688/877: 41 frames
# Processed video 689/877: 43 frames
# Processed video 690/877: 73 frames
# Processed video 691/877: 41 frames
# Processed video 692/877: 57 frames
# Processed video 693/877: 89 frames
# Processed video 694/877: 82 frames
# Processed video 695/877: 115 frames
# Processed video 696/877: 66 frames
# Processed video 697/877: 40 frames
# Processed video 698/877: 138 frames
# Processed video 699/877: 84 frames
# Processed video 700/877: 90 frames
# Processed video 701/877: 167 frames
# Processed video 702/877: 110 frames
# Processed video 703/877: 69 frames
# Processed video 704/877: 44 frames
# Processed video 705/877: 70 frames
# Processed video 706/877: 60 frames
# Processed video 707/877: 63 frames
# Processed video 708/877: 73 frames
# Processed video 709/877: 50 frames
# Processed video 710/877: 107 frames
# Processed video 711/877: 56 frames
# Processed video 712/877: 75 frames
# Processed video 713/877: 70 frames
# Processed video 714/877: 95 frames
# Processed video 715/877: 92 frames
# Processed video 716/877: 78 frames
# Processed video 717/877: 144 frames
# Processed video 718/877: 82 frames
# Processed video 719/877: 82 frames
# Processed video 720/877: 81 frames
# Processed video 721/877: 149 frames
# Processed video 722/877: 90 frames
# Processed video 723/877: 187 frames
# Processed video 724/877: 67 frames
# Processed video 725/877: 41 frames
# Processed video 726/877: 125 frames
# Processed video 727/877: 39 frames
# Processed video 728/877: 178 frames
# Processed video 729/877: 76 frames
# Processed video 730/877: 37 frames
# Processed video 731/877: 80 frames
# Processed video 732/877: 136 frames
# Processed video 733/877: 72 frames
# Processed video 734/877: 45 frames
# Processed video 735/877: 168 frames
# Processed video 736/877: 81 frames
# Processed video 737/877: 115 frames
# Processed video 738/877: 100 frames
# Processed video 739/877: 76 frames
# Processed video 740/877: 88 frames
# Processed video 741/877: 56 frames
# Processed video 742/877: 47 frames
# Processed video 743/877: 68 frames
# Processed video 744/877: 76 frames
# Processed video 745/877: 58 frames
# Processed video 746/877: 44 frames
# Processed video 747/877: 47 frames
# Processed video 748/877: 79 frames
# Processed video 749/877: 100 frames
# Processed video 750/877: 43 frames
# Processed video 751/877: 39 frames
# Processed video 752/877: 47 frames
# Processed video 753/877: 81 frames
# Processed video 754/877: 77 frames
# Processed video 755/877: 191 frames
# Processed video 756/877: 63 frames
# Processed video 757/877: 171 frames
# Processed video 758/877: 151 frames
# Processed video 759/877: 79 frames
# Processed video 760/877: 68 frames
# Processed video 761/877: 68 frames
# Processed video 762/877: 69 frames
# Processed video 763/877: 76 frames
# Processed video 764/877: 184 frames
# Processed video 765/877: 135 frames
# Processed video 766/877: 80 frames
# Processed video 767/877: 101 frames
# Processed video 768/877: 47 frames
# Processed video 769/877: 88 frames
# Processed video 770/877: 178 frames
# Processed video 771/877: 65 frames
# Processed video 772/877: 59 frames
# Processed video 773/877: 73 frames
# Processed video 774/877: 74 frames
# Processed video 775/877: 38 frames
# Processed video 776/877: 49 frames
# Processed video 777/877: 59 frames
# Processed video 778/877: 49 frames
# Processed video 779/877: 61 frames
# Processed video 780/877: 108 frames
# Processed video 781/877: 52 frames
# Processed video 782/877: 70 frames
# Processed video 783/877: 90 frames
# Processed video 784/877: 61 frames
# Processed video 785/877: 142 frames
# Processed video 786/877: 64 frames
# Processed video 787/877: 82 frames
# Processed video 788/877: 178 frames
# Processed video 789/877: 84 frames
# Processed video 790/877: 53 frames
# Processed video 791/877: 53 frames
# Processed video 792/877: 111 frames
# Processed video 793/877: 79 frames
# Processed video 794/877: 37 frames
# Processed video 795/877: 116 frames
# Processed video 796/877: 93 frames
# Processed video 797/877: 53 frames
# Processed video 798/877: 94 frames
# Processed video 799/877: 62 frames
# Processed video 800/877: 91 frames
# Processed video 801/877: 73 frames
# Processed video 802/877: 36 frames
# Processed video 803/877: 49 frames
# Processed video 804/877: 85 frames
# Processed video 805/877: 44 frames
# Processed video 806/877: 102 frames
# Processed video 807/877: 63 frames
# Processed video 808/877: 87 frames
# Processed video 809/877: 99 frames
# Processed video 810/877: 67 frames
# Processed video 811/877: 82 frames
# Processed video 812/877: 86 frames
# Processed video 813/877: 47 frames
# Processed video 814/877: 66 frames
# Processed video 815/877: 68 frames
# Processed video 816/877: 55 frames
# Processed video 817/877: 49 frames
# Processed video 818/877: 138 frames
# Processed video 819/877: 50 frames
# Processed video 820/877: 89 frames
# Processed video 821/877: 157 frames
# Processed video 822/877: 100 frames
# Processed video 823/877: 45 frames
# Processed video 824/877: 93 frames
# Processed video 825/877: 80 frames
# Processed video 826/877: 132 frames
# Processed video 827/877: 70 frames
# Processed video 828/877: 110 frames
# Processed video 829/877: 163 frames
# Processed video 830/877: 77 frames
# Processed video 831/877: 44 frames
# Processed video 832/877: 39 frames
# Processed video 833/877: 63 frames
# Processed video 834/877: 40 frames
# Processed video 835/877: 83 frames
# Processed video 836/877: 48 frames
# Processed video 837/877: 50 frames
# Processed video 838/877: 140 frames
# Processed video 839/877: 92 frames
# Processed video 840/877: 68 frames
# Processed video 841/877: 74 frames
# Processed video 842/877: 38 frames
# Processed video 843/877: 189 frames
# Processed video 844/877: 76 frames
# Processed video 845/877: 92 frames
# Processed video 846/877: 61 frames
# Processed video 847/877: 84 frames
# Processed video 848/877: 60 frames
# Processed video 849/877: 98 frames
# Processed video 850/877: 37 frames
# Processed video 851/877: 68 frames
# Processed video 852/877: 76 frames
# Processed video 853/877: 51 frames
# Processed video 854/877: 142 frames
# Processed video 855/877: 81 frames
# Processed video 856/877: 77 frames
# Processed video 857/877: 72 frames
# Processed video 858/877: 87 frames
# Processed video 859/877: 112 frames
# Processed video 860/877: 67 frames
# Processed video 861/877: 76 frames
# Processed video 862/877: 39 frames
# Processed video 863/877: 41 frames
# Processed video 864/877: 98 frames
# Processed video 865/877: 84 frames
# Processed video 866/877: 53 frames
# Processed video 867/877: 128 frames
# Processed video 868/877: 40 frames
# Processed video 869/877: 124 frames
# Processed video 870/877: 82 frames
# Processed video 871/877: 37 frames
# Processed video 872/877: 112 frames
# Processed video 873/877: 77 frames
# Processed video 874/877: 68 frames
# Processed video 875/877: 90 frames
# Processed video 876/877: 85 frames
# Processed video 877/877: 80 frames
# Combined graph generation completed and saved as combined_graph.pt.

# %%
# Connect images between videos using k-NN
edges_between_videos = connect_videos_with_knn(all_graphs)

# Combine all graphs into one large graph
combined_features = np.vstack([graph[0] for graph in all_graphs])  # Combine feature vectors
combined_node_source = []
combined_node_target = []
combined_edge_attr = []

# Add edges from individual videos to combined graph
for idx, (features, node_source, node_target, edge_attr) in enumerate(all_graphs):
    offset = sum([graph[0].shape[0] for graph in all_graphs[:idx]])  # Calculate offset for current video
    combined_node_source.extend([source + offset for source in node_source])
    combined_node_target.extend([target + offset for target in node_target])
    combined_edge_attr.extend(edge_attr)


# Add inter-video edges to combined graph
combined_node_source.extend([source for source, _ in edges_between_videos])
combined_node_target.extend([target for _, target in edges_between_videos])

# %%
# Create final graph data object with combined data
final_graph_data = Data(
    x=torch.tensor(combined_features, dtype=torch.float32),
    edge_index=torch.tensor([combined_node_source, combined_node_target], dtype=torch.long),
)

# Save the final combined graph data
torch.save(final_graph_data, os.path.join(output_graphs_path, 'combined_graph.pt'))

print('Combined graph generation completed and saved as combined_graph.pt.')

# %%
import os
import glob
import numpy as np
import torch
from torch_geometric.data import Data
from torchvision import models, transforms
from PIL import Image
from sklearn.neighbors import NearestNeighbors
import networkx as nx
import matplotlib.pyplot as plt

# (Include all previous functions here...)

def visualize_graph(graph_data):
    # Create a NetworkX graph from edge_index
    G = nx.Graph()

    # Add nodes with features as node attributes
    for i in range(graph_data.x.shape[0]):
        G.add_node(i, feature=graph_data.x[i].numpy())

    # Add edges from edge_index
    edge_index = graph_data.edge_index.numpy()
    for source, target in zip(edge_index[0], edge_index[1]):
        G.add_edge(source, target)

    # Draw the graph
    plt.figure(figsize=(12, 12))
    
    # Use a layout for better visibility
    pos = nx.spring_layout(G)  # positions for all nodes
    
    # Draw nodes and edges
    nx.draw_networkx_nodes(G, pos, node_size=50)
    nx.draw_networkx_edges(G, pos, alpha=0.5)
    
    plt.title("Graph Visualization")
    plt.axis('off')  # Turn off the axis
    plt.show()

# (Include all previous code for generating graphs...)

# After saving the final combined graph data:
torch.save(final_graph_data, os.path.join(output_graphs_path, 'combined_graph.pt'))

print('Combined graph generation completed and saved as combined_graph.pt.')

# Visualize the combined graph
visualize_graph(final_graph_data)
# Out:
# Combined graph generation completed and saved as combined_graph.pt.
